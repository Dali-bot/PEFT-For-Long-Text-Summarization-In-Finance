# %%
# !pip install datasets transformers trl evaluate huggingface_hub pynvml psutil rouge_score trackio
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (4.0.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.57.1)
# Collecting trl
#   Downloading trl-0.25.0-py3-none-any.whl.metadata (11 kB)
# Collecting evaluate
#   Downloading evaluate-0.4.6-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (0.36.0)
# Requirement already satisfied: pynvml in /usr/local/lib/python3.12/dist-packages (12.0.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (5.9.5)
# Collecting rouge_score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Collecting trackio
#   Downloading trackio-0.8.1-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets) (3.20.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.32.4)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.12/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from datasets) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.6.2)
# Requirement already satisfied: accelerate>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from trl) (1.11.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (1.2.0)
# Requirement already satisfied: nvidia-ml-py<13.0.0a0,>=12.0.0 in /usr/local/lib/python3.12/dist-packages (from pynvml) (12.575.51)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from rouge_score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (from rouge_score) (3.9.1)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.12/dist-packages (from rouge_score) (1.17.0)
# Requirement already satisfied: gradio<6.0.0,>=5.48.0 in /usr/local/lib/python3.12/dist-packages (from gradio[oauth]<6.0.0,>=5.48.0->trackio) (5.49.1)
# Requirement already satisfied: orjson<4.0.0,>=3.0 in /usr/local/lib/python3.12/dist-packages (from trackio) (3.11.4)
# Requirement already satisfied: pillow<12.0.0 in /usr/local/lib/python3.12/dist-packages (from trackio) (11.3.0)
# Collecting plotly<7.0.0,>=6.0.0 (from trackio)
#   Downloading plotly-6.4.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: pydub<1.0.0 in /usr/local/lib/python3.12/dist-packages (from trackio) (0.25.1)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from accelerate>=1.4.0->trl) (2.8.0+cu126)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.13.2)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in /usr/local/lib/python3.12/dist-packages (from gradio<6.0.0,>=5.48.0->gradio[oauth]<6.0.0,>=5.48.0->trackio) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio<6.0.0,>=5.48.0->gradio[oauth]<6.0.0,>=5.48.0->trackio) (4.11.0)
# Requirement already satisfied: brotli>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from gradio<6.0.0,>=5.48.0->gradio[oauth]<6.0.0,>=5.48.0->trackio) (1.2.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /usr/local/lib/python3.12/dist-packages (from gradio<6.0.0,>=5.48.0->gradio[oauth]<6.0.0,>=5.48.0->trackio) (0.121.0)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.12/dist-packages (from gradio<6.0.0,>=5.48.0->gradio[oauth]<6.0.0,>=5.48.0->trackio) (0.6.4)
# Requirement already satisfied: gradio-client==1.13.3 in /usr/local/lib/python3.12/dist-packages (from gradio<6.0.0,>=5.48.0->gradio[oauth]<6.0.0,>=5.48.0->trackio) (1.13.3)
# Requirement already satisfied: groovy~=0.1 in /usr/local/lib/python3.12/dist-packages (from gradio<6.0.0,>=5.48.0->gradio[oauth]<6.0.0,>=5.48.0->trackio) (0.1.2)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in /usr/local/lib/python3.12/dist-packages (from gradio<6.0.0,>=5.48.0->gradio[oauth]<6.0.0,>=5.48.0->trackio) (0.28.1)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.12/dist-packages (from gradio<6.0.0,>=5.48.0->gradio[oauth]<6.0.0,>=5.48.0->trackio) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio<6.0.0,>=5.48.0->gradio[oauth]<6.0.0,>=5.48.0->trackio) (3.0.3)
# Requirement already satisfied: pydantic<2.12,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio<6.0.0,>=5.48.0->gradio[oauth]<6.0.0,>=5.48.0->trackio) (2.11.10)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.12/dist-packages (from gradio<6.0.0,>=5.48.0->gradio[oauth]<6.0.0,>=5.48.0->trackio) (0.0.20)
# Requirement already satisfied: ruff>=0.9.3 in /usr/local/lib/python3.12/dist-packages (from gradio<6.0.0,>=5.48.0->gradio[oauth]<6.0.0,>=5.48.0->trackio) (0.14.3)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /usr/local/lib/python3.12/dist-packages (from gradio<6.0.0,>=5.48.0->gradio[oauth]<6.0.0,>=5.48.0->trackio) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio<6.0.0,>=5.48.0->gradio[oauth]<6.0.0,>=5.48.0->trackio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from gradio<6.0.0,>=5.48.0->gradio[oauth]<6.0.0,>=5.48.0->trackio) (0.49.3)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from gradio<6.0.0,>=5.48.0->gradio[oauth]<6.0.0,>=5.48.0->trackio) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.12/dist-packages (from gradio<6.0.0,>=5.48.0->gradio[oauth]<6.0.0,>=5.48.0->trackio) (0.20.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from gradio<6.0.0,>=5.48.0->gradio[oauth]<6.0.0,>=5.48.0->trackio) (0.38.0)
# Requirement already satisfied: websockets<16.0,>=13.0 in /usr/local/lib/python3.12/dist-packages (from gradio-client==1.13.3->gradio<6.0.0,>=5.48.0->gradio[oauth]<6.0.0,>=5.48.0->trackio) (15.0.1)
# Requirement already satisfied: authlib in /usr/local/lib/python3.12/dist-packages (from gradio[oauth]<6.0.0,>=5.48.0->trackio) (1.6.5)
# Requirement already satisfied: itsdangerous in /usr/local/lib/python3.12/dist-packages (from gradio[oauth]<6.0.0,>=5.48.0->trackio) (2.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: narwhals>=1.15.1 in /usr/local/lib/python3.12/dist-packages (from plotly<7.0.0,>=6.0.0->trackio) (2.10.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2025.10.5)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk->rouge_score) (8.3.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk->rouge_score) (1.5.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0,>=3.0->gradio<6.0.0,>=5.48.0->gradio[oauth]<6.0.0,>=5.48.0->trackio) (1.3.1)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi<1.0,>=0.115.2->gradio<6.0.0,>=5.48.0->gradio[oauth]<6.0.0,>=5.48.0->trackio) (0.0.3)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.24.1->gradio<6.0.0,>=5.48.0->gradio[oauth]<6.0.0,>=5.48.0->trackio) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio<6.0.0,>=5.48.0->gradio[oauth]<6.0.0,>=5.48.0->trackio) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<2.12,>=2.0->gradio<6.0.0,>=5.48.0->gradio[oauth]<6.0.0,>=5.48.0->trackio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<2.12,>=2.0->gradio<6.0.0,>=5.48.0->gradio[oauth]<6.0.0,>=5.48.0->trackio) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<2.12,>=2.0->gradio<6.0.0,>=5.48.0->gradio[oauth]<6.0.0,>=5.48.0->trackio) (0.4.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (3.5)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (3.4.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio<6.0.0,>=5.48.0->gradio[oauth]<6.0.0,>=5.48.0->trackio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio<6.0.0,>=5.48.0->gradio[oauth]<6.0.0,>=5.48.0->trackio) (13.9.4)
# Requirement already satisfied: cryptography in /usr/local/lib/python3.12/dist-packages (from authlib->gradio[oauth]<6.0.0,>=5.48.0->trackio) (43.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio<6.0.0,>=5.48.0->gradio[oauth]<6.0.0,>=5.48.0->trackio) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio<6.0.0,>=5.48.0->gradio[oauth]<6.0.0,>=5.48.0->trackio) (2.19.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate>=1.4.0->trl) (1.3.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography->authlib->gradio[oauth]<6.0.0,>=5.48.0->trackio) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography->authlib->gradio[oauth]<6.0.0,>=5.48.0->trackio) (2.23)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio<6.0.0,>=5.48.0->gradio[oauth]<6.0.0,>=5.48.0->trackio) (0.1.2)
# Downloading trl-0.25.0-py3-none-any.whl (462 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.8/462.8 kB 31.6 MB/s eta 0:00:00
# Downloading evaluate-0.4.6-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 9.1 MB/s eta 0:00:00
# Downloading trackio-0.8.1-py3-none-any.whl (874 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 875.0/875.0 kB 60.0 MB/s eta 0:00:00
# Downloading plotly-6.4.0-py3-none-any.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 124.0 MB/s eta 0:00:00
# Building wheels for collected packages: rouge_score
#   Building wheel for rouge_score (setup.py) ... done
#   Created wheel for rouge_score: filename=rouge_score-0.1.2-py3-none-any.whl size=24934 sha256=67804b6f2234cb3fb392360cd362db9ef350518a042a6dd38e572f81606c62ee
#   Stored in directory: /root/.cache/pip/wheels/85/9d/af/01feefbe7d55ef5468796f0c68225b6788e85d9d0a281e7a70
# Successfully built rouge_score
# Installing collected packages: plotly, rouge_score, trl, evaluate, trackio
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.24.1
#     Uninstalling plotly-5.24.1:
#       Successfully uninstalled plotly-5.24.1
# Successfully installed evaluate-0.4.6 plotly-6.4.0 rouge_score-0.1.2 trackio-0.8.1 trl-0.25.0

# %%
from datasets import load_dataset
from trl import SFTTrainer, SFTConfig
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch
import evaluate
from transformers import TrainerCallback
import time
from huggingface_hub import login
from pynvml import nvmlInit, nvmlDeviceGetHandleByIndex, nvmlDeviceGetMemoryInfo
import pynvml
import psutil
from peft import AdaLoraConfig, get_peft_model
from accelerate import init_empty_weights, load_checkpoint_and_dispatch

torch.cuda.empty_cache()
print("login")

login(token="YourToken")

print("data is loading")

ds_train = load_dataset('csv', data_files='./drive/MyDrive/text_only_train_data.csv')
ds_val = load_dataset('csv', data_files={'validation':'./drive/MyDrive/text_only_val_data.csv'})

train = ds_train["train"]

val = ds_val["validation"]

# Optionally add prefix on the validation set for instruction tuning
def add_prefix(example):
    prefix = "Summarize the following document: "
    example["document"] = prefix + example["document"]
    return example

train = train.map(add_prefix)
val = val.map(add_prefix)

print("model loading")

model_id = "mistralai/Mistral-7B-Instruct-v0.3"
tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForCausalLM.from_pretrained(model_id, dtype=torch.bfloat16, device_map="auto")

print("Loading ROUGE metric...")
rouge = evaluate.load("rouge")

def compute_metrics(eval_preds):
    predictions, labels = eval_preds
    # decode token IDs into strings if needed (tokenizer needed here)
    decoded_preds = tokenizer.batch_decode(predictions, skip_special_tokens=True)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)

    # Run rouge evaluation on decoded text
    result = rouge.compute(predictions=decoded_preds, references=decoded_labels)
    print("ROUGE Log", result)
    return {
        "rouge1": result["rouge1"],
        "rouge2": result["rouge2"],
        "rougeL": result["rougeL"]
    }
class ResourceLoggingCallback(TrainerCallback):
    def __init__(self, log_interval=60):
        super().__init__()
        self.log_interval = log_interval  # seconds
        self.last_log_time = time.time()
        nvmlInit()
        self.handle = nvmlDeviceGetHandleByIndex(0)  # GPU 0

    def on_step_end(self, args, state, control, **kwargs):
        current_time = time.time()
        if current_time - self.last_log_time >= self.log_interval:
            # Log GPU memory
            mem_info = nvmlDeviceGetMemoryInfo(self.handle)
            gpu_used = mem_info.used / (1024 ** 3)
            gpu_total = mem_info.total / (1024 ** 3)

            # Log CPU/RAM usage
            cpu_percent = psutil.cpu_percent()
            ram_info = psutil.virtual_memory()

            print(f"[Resource Log | Step {state.global_step}] "
                  f"GPU Memory Used: {gpu_used:.2f} GB / {gpu_total:.2f} GB, "
                  f"CPU Usage: {cpu_percent}%, "
                  f"RAM Usage: {ram_info.used / (1024 ** 3):.2f} GB / {ram_info.total / (1024 ** 3):.2f} GB")

            self.last_log_time = current_time

    def on_train_end(self, args, state, control, **kwargs):
        total_flos = getattr(state, 'total_flos', None)
        if total_flos is not None:
            print(f"Total FLOPs during training: {total_flos}")
        else:
            print("Total FLOPs information not available.")

print(model_id)
print("training")
adalora_config = AdaLoraConfig(
    init_r=64,
    target_r = 32,# rank for LoRA matrices
    target_modules=["q_proj", "v_proj"],  # modules to adapt
    lora_alpha=64,
    lora_dropout=0.1,
    bias="none",
    task_type="CAUSAL_LM",
    total_step=471
)

# Wrap the base model with AdaLoRA PEFT model
ada_lora_model = get_peft_model(model, adalora_config)

training_args = SFTConfig(
    dataset_text_field="document",
    learning_rate=2e-4,
    per_device_train_batch_size=1, # Further reduced batch size
    per_device_eval_batch_size=1, # Further reduced eval batch size
    gradient_accumulation_steps=64, # Increased gradient accumulation steps
    num_train_epochs=2,
    report_to=["trackio"],  # Add this to save checkpoints
    save_strategy="epoch",
    output_dir = "./drive/MyDrive/Results_AdaLora/Mistral/sft-mistral-ada-lora",  # Save checkpoint at end of each epoch
    gradient_checkpointing=True # Enable gradient checkpointing
)

trainer = SFTTrainer(
        model=ada_lora_model,  # reload or clone model if needed
        train_dataset=train,
        eval_dataset=val,
        args=training_args,
        compute_metrics=compute_metrics,
        callbacks=[ResourceLoggingCallback(log_interval=120)],
        processing_class=tokenizer,
    )
trainer.train()
trainer.save_model("./drive/MyDrive/Results_AdaLora/Mistral/my_trained_model")
trainer.save_state()
# Out:
# login
# data is loading
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Map:   0%|          | 0/16820 [00:00<?, ? examples/s]
# Map:   0%|          | 0/2102 [00:00<?, ? examples/s]
# model loading
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/587k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/601 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 3 files:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/4.55G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Loading ROUGE metric...
# Downloading builder script: 0.00B [00:00, ?B/s]
# mistralai/Mistral-7B-Instruct-v0.3
# training
# Adding EOS to train dataset:   0%|          | 0/16820 [00:00<?, ? examples/s]
# Tokenizing train dataset:   0%|          | 0/16820 [00:00<?, ? examples/s]
# Truncating train dataset:   0%|          | 0/16820 [00:00<?, ? examples/s]
# Adding EOS to eval dataset:   0%|          | 0/2102 [00:00<?, ? examples/s]
# Tokenizing eval dataset:   0%|          | 0/2102 [00:00<?, ? examples/s]
# Truncating eval dataset:   0%|          | 0/2102 [00:00<?, ? examples/s]
# The model is already on multiple devices. Skipping the move to device specified in `args`.
# * Trackio project initialized: huggingface
# * Trackio metrics will be synced to Hugging Face Dataset: Dali-bot/trackio-dataset
# * Found existing space: https://huggingface.co/spaces/Dali-bot/trackio
# * View dashboard by going to: https://Dali-bot-trackio.hf.space/
# <div><iframe src="https://Dali-bot-trackio.hf.space/" width="100%" height="1000px" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# * Created new run: Dali-bot-1762764337
# [Resource Log | Step 1] GPU Memory Used: 15.75 GB / 40.00 GB, CPU Usage: 6.1%, RAM Usage: 5.46 GB / 83.47 GB
#     <div>
#
#       <progress value='526' max='526' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [526/526 3:18:23, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>144.606600</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>95.605600</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>52.900400</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>29.039900</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>21.862300</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>13.017300</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>5.598400</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>4.108400</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>3.001200</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>2.725200</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>2.529500</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>2.450200</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>2.404000</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>2.356900</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>2.345300</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>2.296500</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>2.300800</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>2.250800</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>2.235100</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>2.226600</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>2.205300</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>2.171000</td>
#     </tr>
#     <tr>
#       <td>230</td>
#       <td>2.174100</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>2.138700</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>2.093200</td>
#     </tr>
#     <tr>
#       <td>260</td>
#       <td>2.093700</td>
#     </tr>
#     <tr>
#       <td>270</td>
#       <td>2.063300</td>
#     </tr>
#     <tr>
#       <td>280</td>
#       <td>2.059300</td>
#     </tr>
#     <tr>
#       <td>290</td>
#       <td>2.030600</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>2.029800</td>
#     </tr>
#     <tr>
#       <td>310</td>
#       <td>2.020900</td>
#     </tr>
#     <tr>
#       <td>320</td>
#       <td>1.987900</td>
#     </tr>
#     <tr>
#       <td>330</td>
#       <td>1.961300</td>
#     </tr>
#     <tr>
#       <td>340</td>
#       <td>1.956000</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>1.916700</td>
#     </tr>
#     <tr>
#       <td>360</td>
#       <td>1.907500</td>
#     </tr>
#     <tr>
#       <td>370</td>
#       <td>1.898100</td>
#     </tr>
#     <tr>
#       <td>380</td>
#       <td>1.885100</td>
#     </tr>
#     <tr>
#       <td>390</td>
#       <td>1.878900</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>1.843900</td>
#     </tr>
#     <tr>
#       <td>410</td>
#       <td>1.839500</td>
#     </tr>
#     <tr>
#       <td>420</td>
#       <td>1.790000</td>
#     </tr>
#     <tr>
#       <td>430</td>
#       <td>1.773500</td>
#     </tr>
#     <tr>
#       <td>440</td>
#       <td>1.757800</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>1.746500</td>
#     </tr>
#     <tr>
#       <td>460</td>
#       <td>1.725000</td>
#     </tr>
#     <tr>
#       <td>470</td>
#       <td>1.700600</td>
#     </tr>
#     <tr>
#       <td>480</td>
#       <td>1.693100</td>
#     </tr>
#     <tr>
#       <td>490</td>
#       <td>1.660500</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>1.675900</td>
#     </tr>
#     <tr>
#       <td>510</td>
#       <td>1.632700</td>
#     </tr>
#     <tr>
#       <td>520</td>
#       <td>1.636800</td>
#     </tr>
#   </tbody>
# </table><p>
# [Resource Log | Step 7] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 5.47 GB / 83.47 GB
# [Resource Log | Step 13] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.46 GB / 83.47 GB
# [Resource Log | Step 19] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.45 GB / 83.47 GB
# [Resource Log | Step 25] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.45 GB / 83.47 GB
# [Resource Log | Step 31] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.44 GB / 83.47 GB
# [Resource Log | Step 37] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.42 GB / 83.47 GB
# [Resource Log | Step 43] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.43 GB / 83.47 GB
# [Resource Log | Step 49] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.44 GB / 83.47 GB
# [Resource Log | Step 55] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.43 GB / 83.47 GB
# [Resource Log | Step 61] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.43 GB / 83.47 GB
# [Resource Log | Step 67] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.43 GB / 83.47 GB
# [Resource Log | Step 73] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.41 GB / 83.47 GB
# [Resource Log | Step 79] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.41 GB / 83.47 GB
# [Resource Log | Step 85] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.42 GB / 83.47 GB
# [Resource Log | Step 91] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.41 GB / 83.47 GB
# [Resource Log | Step 97] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.40 GB / 83.47 GB
# [Resource Log | Step 103] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.41 GB / 83.47 GB
# [Resource Log | Step 109] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.39 GB / 83.47 GB
# [Resource Log | Step 115] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 13.3%, RAM Usage: 5.86 GB / 83.47 GB
# [Resource Log | Step 121] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.47 GB / 83.47 GB
# [Resource Log | Step 127] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.46 GB / 83.47 GB
# [Resource Log | Step 133] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.49 GB / 83.47 GB
# [Resource Log | Step 139] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.47 GB / 83.47 GB
# [Resource Log | Step 145] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.46 GB / 83.47 GB
# [Resource Log | Step 151] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.47 GB / 83.47 GB
# [Resource Log | Step 157] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.48 GB / 83.47 GB
# [Resource Log | Step 163] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.44 GB / 83.47 GB
# [Resource Log | Step 169] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.46 GB / 83.47 GB
# [Resource Log | Step 175] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.49 GB / 83.47 GB
# [Resource Log | Step 181] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.48 GB / 83.47 GB
# [Resource Log | Step 187] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.44 GB / 83.47 GB
# [Resource Log | Step 193] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.47 GB / 83.47 GB
# [Resource Log | Step 199] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.45 GB / 83.47 GB
# [Resource Log | Step 205] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.45 GB / 83.47 GB
# [Resource Log | Step 211] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.44 GB / 83.47 GB
# [Resource Log | Step 217] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.44 GB / 83.47 GB
# [Resource Log | Step 223] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.44 GB / 83.47 GB
# [Resource Log | Step 229] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.47 GB / 83.47 GB
# [Resource Log | Step 235] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.43 GB / 83.47 GB
# [Resource Log | Step 241] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.47 GB / 83.47 GB
# [Resource Log | Step 247] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 5.45 GB / 83.47 GB
# [Resource Log | Step 253] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.46 GB / 83.47 GB
# [Resource Log | Step 259] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.46 GB / 83.47 GB
# [Resource Log | Step 265] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 5.46 GB / 83.47 GB
# [Resource Log | Step 271] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.46 GB / 83.47 GB
# [Resource Log | Step 277] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.46 GB / 83.47 GB
# [Resource Log | Step 283] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.47 GB / 83.47 GB
# [Resource Log | Step 289] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.45 GB / 83.47 GB
# [Resource Log | Step 295] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.48 GB / 83.47 GB
# [Resource Log | Step 301] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 5.46 GB / 83.47 GB
# [Resource Log | Step 307] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.46 GB / 83.47 GB
# [Resource Log | Step 313] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.46 GB / 83.47 GB
# [Resource Log | Step 319] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.45 GB / 83.47 GB
# [Resource Log | Step 325] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.46 GB / 83.47 GB
# [Resource Log | Step 331] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.46 GB / 83.47 GB
# [Resource Log | Step 337] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.46 GB / 83.47 GB
# [Resource Log | Step 343] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.44 GB / 83.47 GB
# [Resource Log | Step 349] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.46 GB / 83.47 GB
# [Resource Log | Step 355] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.46 GB / 83.47 GB
# [Resource Log | Step 361] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.44 GB / 83.47 GB
# [Resource Log | Step 367] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.47 GB / 83.47 GB
# [Resource Log | Step 373] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.46 GB / 83.47 GB
# [Resource Log | Step 379] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.46 GB / 83.47 GB
# [Resource Log | Step 385] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.46 GB / 83.47 GB
# [Resource Log | Step 391] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.46 GB / 83.47 GB
# [Resource Log | Step 397] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.46 GB / 83.47 GB
# [Resource Log | Step 403] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 5.43 GB / 83.47 GB
# [Resource Log | Step 409] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.46 GB / 83.47 GB
# [Resource Log | Step 415] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.45 GB / 83.47 GB
# [Resource Log | Step 421] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.45 GB / 83.47 GB
# [Resource Log | Step 427] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.46 GB / 83.47 GB
# [Resource Log | Step 433] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.45 GB / 83.47 GB
# [Resource Log | Step 439] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 5.47 GB / 83.47 GB
# [Resource Log | Step 445] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.44 GB / 83.47 GB
# [Resource Log | Step 451] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.44 GB / 83.47 GB
# [Resource Log | Step 457] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.46 GB / 83.47 GB
# [Resource Log | Step 463] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.44 GB / 83.47 GB
# [Resource Log | Step 469] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.45 GB / 83.47 GB
# [Resource Log | Step 475] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 5.45 GB / 83.47 GB
# [Resource Log | Step 481] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.44 GB / 83.47 GB
# [Resource Log | Step 487] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.45 GB / 83.47 GB
# [Resource Log | Step 493] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.46 GB / 83.47 GB
# [Resource Log | Step 499] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.44 GB / 83.47 GB
# [Resource Log | Step 505] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.47 GB / 83.47 GB
# [Resource Log | Step 511] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.47 GB / 83.47 GB
# [Resource Log | Step 517] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.44 GB / 83.47 GB
# [Resource Log | Step 523] GPU Memory Used: 15.85 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.47 GB / 83.47 GB
# * Run finished. Uploading logs to Trackio (please wait...)
# Total FLOPs during training: 1.4759466662363136e+18

# %%
from datasets import load_dataset
from trl import SFTTrainer, SFTConfig
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch
import evaluate
from transformers import TrainerCallback
import time
from huggingface_hub import login
from pynvml import nvmlInit, nvmlDeviceGetHandleByIndex, nvmlDeviceGetMemoryInfo
import pynvml
import psutil
from peft import AdaLoraConfig, get_peft_model
from accelerate import init_empty_weights, load_checkpoint_and_dispatch

torch.cuda.empty_cache()
print("login")

login(token="YourToken")

print("data is loading")

ds_train = load_dataset('csv', data_files='./drive/MyDrive/text_only_train_data.csv')
ds_val = load_dataset('csv', data_files={'validation':'./drive/MyDrive/text_only_val_data.csv'})

train = ds_train["train"]

val = ds_val["validation"]

# Optionally add prefix on the validation set for instruction tuning
def add_prefix(example):
    prefix = "Summarize the following document: "
    example["document"] = prefix + example["document"]
    return example

train = train.map(add_prefix)
val = val.map(add_prefix)

print("model loading")

model_id = "CohereLabs/c4ai-command-r7b-12-2024"
tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForCausalLM.from_pretrained(model_id, dtype=torch.bfloat16, device_map="auto")

print("Loading ROUGE metric...")
rouge = evaluate.load("rouge")

def compute_metrics(eval_preds):
    predictions, labels = eval_preds
    # decode token IDs into strings if needed (tokenizer needed here)
    decoded_preds = tokenizer.batch_decode(predictions, skip_special_tokens=True)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)

    # Run rouge evaluation on decoded text
    result = rouge.compute(predictions=decoded_preds, references=decoded_labels)
    print("ROUGE Log", result)
    return {
        "rouge1": result["rouge1"],
        "rouge2": result["rouge2"],
        "rougeL": result["rougeL"]
    }
class ResourceLoggingCallback(TrainerCallback):
    def __init__(self, log_interval=60):
        super().__init__()
        self.log_interval = log_interval  # seconds
        self.last_log_time = time.time()
        nvmlInit()
        self.handle = nvmlDeviceGetHandleByIndex(0)  # GPU 0

    def on_step_end(self, args, state, control, **kwargs):
        current_time = time.time()
        if current_time - self.last_log_time >= self.log_interval:
            # Log GPU memory
            mem_info = nvmlDeviceGetMemoryInfo(self.handle)
            gpu_used = mem_info.used / (1024 ** 3)
            gpu_total = mem_info.total / (1024 ** 3)

            # Log CPU/RAM usage
            cpu_percent = psutil.cpu_percent()
            ram_info = psutil.virtual_memory()

            print(f"[Resource Log | Step {state.global_step}] "
                  f"GPU Memory Used: {gpu_used:.2f} GB / {gpu_total:.2f} GB, "
                  f"CPU Usage: {cpu_percent}%, "
                  f"RAM Usage: {ram_info.used / (1024 ** 3):.2f} GB / {ram_info.total / (1024 ** 3):.2f} GB")

            self.last_log_time = current_time

    def on_train_end(self, args, state, control, **kwargs):
        total_flos = getattr(state, 'total_flos', None)
        if total_flos is not None:
            print(f"Total FLOPs during training: {total_flos}")
        else:
            print("Total FLOPs information not available.")

print(model_id)
print("training")
adalora_config = AdaLoraConfig(
    init_r=64,
    target_r = 32,# rank for LoRA matrices
    target_modules=["q_proj", "v_proj"],  # modules to adapt
    lora_alpha=64,
    lora_dropout=0.1,
    bias="none",
    task_type="CAUSAL_LM",
    total_step=471
)

# Wrap the base model with AdaLoRA PEFT model
ada_lora_model = get_peft_model(model, adalora_config)

training_args = SFTConfig(
    dataset_text_field="document",
    learning_rate=2e-4,
    per_device_train_batch_size=1, # Further reduced batch size
    per_device_eval_batch_size=1, # Further reduced eval batch size
    gradient_accumulation_steps=64, # Increased gradient accumulation steps
    num_train_epochs=2,
    report_to=["trackio"],  # Add this to save checkpoints
    save_strategy="epoch",
    output_dir = "./drive/MyDrive/Results_AdaLora/Command/sft-command-ada-lora",  # Save checkpoint at end of each epoch
    gradient_checkpointing=True # Enable gradient checkpointing
)

trainer = SFTTrainer(
        model=ada_lora_model,  # reload or clone model if needed
        train_dataset=train,
        eval_dataset=val,
        args=training_args,
        compute_metrics=compute_metrics,
        callbacks=[ResourceLoggingCallback(log_interval=120)],
        processing_class=tokenizer,
    )
trainer.train()
trainer.save_model("./drive/MyDrive/Results_AdaLora/Command/my_trained_command_model")
trainer.save_state()
# Out:
# login
# data is loading
# Map:   0%|          | 0/16820 [00:00<?, ? examples/s]
# Map:   0%|          | 0/2102 [00:00<?, ? examples/s]
# model loading
# tokenizer_config.json:   0%|          | 0.00/45.0k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/20.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/664 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.02k [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/21.0k [00:00<?, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/178 [00:00<?, ?B/s]
# Loading ROUGE metric...
# CohereLabs/c4ai-command-r7b-12-2024
# training
# Adding EOS to train dataset:   0%|          | 0/16820 [00:00<?, ? examples/s]
# Tokenizing train dataset:   0%|          | 0/16820 [00:00<?, ? examples/s]
# Truncating train dataset:   0%|          | 0/16820 [00:00<?, ? examples/s]
# Adding EOS to eval dataset:   0%|          | 0/2102 [00:00<?, ? examples/s]
# Tokenizing eval dataset:   0%|          | 0/2102 [00:00<?, ? examples/s]
# Truncating eval dataset:   0%|          | 0/2102 [00:00<?, ? examples/s]
# The model is already on multiple devices. Skipping the move to device specified in `args`.
# * Created new run: Dali-bot-1762776522
# [Resource Log | Step 1] GPU Memory Used: 20.65 GB / 40.00 GB, CPU Usage: 13.8%, RAM Usage: 5.72 GB / 83.47 GB
#     <div>
#
#       <progress value='526' max='526' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [526/526 3:37:24, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>144.767600</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>95.774300</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>53.062900</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>29.206700</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>22.032100</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>13.208400</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>5.804400</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>4.307700</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>3.208700</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>2.937100</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>2.745200</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>2.661100</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>2.623700</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>2.584300</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>2.583500</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>2.540100</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>2.533500</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>2.476600</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>2.465800</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>2.460000</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>2.446400</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>2.404500</td>
#     </tr>
#     <tr>
#       <td>230</td>
#       <td>2.405800</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>2.367500</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>2.334300</td>
#     </tr>
#     <tr>
#       <td>260</td>
#       <td>2.327700</td>
#     </tr>
#     <tr>
#       <td>270</td>
#       <td>2.297300</td>
#     </tr>
#     <tr>
#       <td>280</td>
#       <td>2.289700</td>
#     </tr>
#     <tr>
#       <td>290</td>
#       <td>2.259300</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>2.256100</td>
#     </tr>
#     <tr>
#       <td>310</td>
#       <td>2.249200</td>
#     </tr>
#     <tr>
#       <td>320</td>
#       <td>2.221500</td>
#     </tr>
#     <tr>
#       <td>330</td>
#       <td>2.195200</td>
#     </tr>
#     <tr>
#       <td>340</td>
#       <td>2.192100</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>2.154200</td>
#     </tr>
#     <tr>
#       <td>360</td>
#       <td>2.138600</td>
#     </tr>
#     <tr>
#       <td>370</td>
#       <td>2.131000</td>
#     </tr>
#     <tr>
#       <td>380</td>
#       <td>2.124400</td>
#     </tr>
#     <tr>
#       <td>390</td>
#       <td>2.112000</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>2.075500</td>
#     </tr>
#     <tr>
#       <td>410</td>
#       <td>2.076000</td>
#     </tr>
#     <tr>
#       <td>420</td>
#       <td>2.021400</td>
#     </tr>
#     <tr>
#       <td>430</td>
#       <td>2.002200</td>
#     </tr>
#     <tr>
#       <td>440</td>
#       <td>1.985400</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>1.988000</td>
#     </tr>
#     <tr>
#       <td>460</td>
#       <td>1.953600</td>
#     </tr>
#     <tr>
#       <td>470</td>
#       <td>1.925100</td>
#     </tr>
#     <tr>
#       <td>480</td>
#       <td>1.930400</td>
#     </tr>
#     <tr>
#       <td>490</td>
#       <td>1.887500</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>1.903000</td>
#     </tr>
#     <tr>
#       <td>510</td>
#       <td>1.864100</td>
#     </tr>
#     <tr>
#       <td>520</td>
#       <td>1.864400</td>
#     </tr>
#   </tbody>
# </table><p>
# [Resource Log | Step 6] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 5.76 GB / 83.47 GB
# [Resource Log | Step 11] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 5.73 GB / 83.47 GB
# [Resource Log | Step 16] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.74 GB / 83.47 GB
# [Resource Log | Step 21] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.74 GB / 83.47 GB
# [Resource Log | Step 26] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.74 GB / 83.47 GB
# [Resource Log | Step 31] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.73 GB / 83.47 GB
# [Resource Log | Step 36] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.74 GB / 83.47 GB
# [Resource Log | Step 41] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 5.71 GB / 83.47 GB
# [Resource Log | Step 46] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.72 GB / 83.47 GB
# [Resource Log | Step 51] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.71 GB / 83.47 GB
# [Resource Log | Step 56] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.70 GB / 83.47 GB
# [Resource Log | Step 61] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.70 GB / 83.47 GB
# [Resource Log | Step 66] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.71 GB / 83.47 GB
# [Resource Log | Step 71] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 5.71 GB / 83.47 GB
# [Resource Log | Step 76] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.70 GB / 83.47 GB
# [Resource Log | Step 81] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.70 GB / 83.47 GB
# [Resource Log | Step 86] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.72 GB / 83.47 GB
# [Resource Log | Step 91] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.72 GB / 83.47 GB
# [Resource Log | Step 96] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.73 GB / 83.47 GB
# [Resource Log | Step 101] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 5.69 GB / 83.47 GB
# [Resource Log | Step 106] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.68 GB / 83.47 GB
# [Resource Log | Step 111] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.68 GB / 83.47 GB
# [Resource Log | Step 116] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 14.0%, RAM Usage: 7.47 GB / 83.47 GB
# [Resource Log | Step 121] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.48 GB / 83.47 GB
# [Resource Log | Step 126] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.49 GB / 83.47 GB
# [Resource Log | Step 131] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.48 GB / 83.47 GB
# [Resource Log | Step 136] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.46 GB / 83.47 GB
# [Resource Log | Step 141] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.46 GB / 83.47 GB
# [Resource Log | Step 146] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 7.46 GB / 83.47 GB
# [Resource Log | Step 151] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.47 GB / 83.47 GB
# [Resource Log | Step 156] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.47 GB / 83.47 GB
# [Resource Log | Step 161] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.48 GB / 83.47 GB
# [Resource Log | Step 166] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.45 GB / 83.47 GB
# [Resource Log | Step 171] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.45 GB / 83.47 GB
# [Resource Log | Step 176] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.46 GB / 83.47 GB
# [Resource Log | Step 181] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.44 GB / 83.47 GB
# [Resource Log | Step 186] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.45 GB / 83.47 GB
# [Resource Log | Step 191] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.7%, RAM Usage: 7.45 GB / 83.47 GB
# [Resource Log | Step 196] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.43 GB / 83.47 GB
# [Resource Log | Step 201] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.46 GB / 83.47 GB
# [Resource Log | Step 206] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.44 GB / 83.47 GB
# [Resource Log | Step 211] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.44 GB / 83.47 GB
# [Resource Log | Step 216] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.45 GB / 83.47 GB
# [Resource Log | Step 221] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.44 GB / 83.47 GB
# [Resource Log | Step 226] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.43 GB / 83.47 GB
# [Resource Log | Step 231] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.43 GB / 83.47 GB
# [Resource Log | Step 236] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.43 GB / 83.47 GB
# [Resource Log | Step 241] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.43 GB / 83.47 GB
# [Resource Log | Step 246] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.40 GB / 83.47 GB
# [Resource Log | Step 251] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.43 GB / 83.47 GB
# [Resource Log | Step 256] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.43 GB / 83.47 GB
# [Resource Log | Step 261] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.44 GB / 83.47 GB
# [Resource Log | Step 266] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.46 GB / 83.47 GB
# [Resource Log | Step 271] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.41 GB / 83.47 GB
# [Resource Log | Step 276] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.41 GB / 83.47 GB
# [Resource Log | Step 281] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.47 GB / 83.47 GB
# [Resource Log | Step 286] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.45 GB / 83.47 GB
# [Resource Log | Step 291] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.45 GB / 83.47 GB
# [Resource Log | Step 296] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.44 GB / 83.47 GB
# [Resource Log | Step 301] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.43 GB / 83.47 GB
# [Resource Log | Step 306] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.43 GB / 83.47 GB
# [Resource Log | Step 311] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.43 GB / 83.47 GB
# [Resource Log | Step 316] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.43 GB / 83.47 GB
# [Resource Log | Step 321] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.41 GB / 83.47 GB
# [Resource Log | Step 326] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 7.45 GB / 83.47 GB
# [Resource Log | Step 331] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 7.44 GB / 83.47 GB
# [Resource Log | Step 336] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.42 GB / 83.47 GB
# [Resource Log | Step 341] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.44 GB / 83.47 GB
# [Resource Log | Step 346] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 7.43 GB / 83.47 GB
# [Resource Log | Step 351] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.44 GB / 83.47 GB
# [Resource Log | Step 356] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.41 GB / 83.47 GB
# [Resource Log | Step 361] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.43 GB / 83.47 GB
# [Resource Log | Step 366] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.7%, RAM Usage: 7.44 GB / 83.47 GB
# [Resource Log | Step 371] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.7%, RAM Usage: 7.45 GB / 83.47 GB
# [Resource Log | Step 376] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.44 GB / 83.47 GB
# [Resource Log | Step 381] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.45 GB / 83.47 GB
# [Resource Log | Step 386] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.42 GB / 83.47 GB
# [Resource Log | Step 391] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.43 GB / 83.47 GB
# [Resource Log | Step 396] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.43 GB / 83.47 GB
# [Resource Log | Step 401] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.42 GB / 83.47 GB
# [Resource Log | Step 406] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.43 GB / 83.47 GB
# [Resource Log | Step 411] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.7%, RAM Usage: 7.42 GB / 83.47 GB
# [Resource Log | Step 416] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.7%, RAM Usage: 7.45 GB / 83.47 GB
# [Resource Log | Step 421] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.45 GB / 83.47 GB
# [Resource Log | Step 426] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.42 GB / 83.47 GB
# [Resource Log | Step 431] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.43 GB / 83.47 GB
# [Resource Log | Step 436] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.43 GB / 83.47 GB
# [Resource Log | Step 441] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.44 GB / 83.47 GB
# [Resource Log | Step 446] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.45 GB / 83.47 GB
# [Resource Log | Step 451] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.43 GB / 83.47 GB
# [Resource Log | Step 456] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.45 GB / 83.47 GB
# [Resource Log | Step 461] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.7%, RAM Usage: 7.44 GB / 83.47 GB
# [Resource Log | Step 466] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.43 GB / 83.47 GB
# [Resource Log | Step 471] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.43 GB / 83.47 GB
# [Resource Log | Step 476] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.44 GB / 83.47 GB
# [Resource Log | Step 481] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.43 GB / 83.47 GB
# [Resource Log | Step 486] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.45 GB / 83.47 GB
# [Resource Log | Step 491] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.43 GB / 83.47 GB
# [Resource Log | Step 496] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.43 GB / 83.47 GB
# [Resource Log | Step 501] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.46 GB / 83.47 GB
# [Resource Log | Step 506] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.7%, RAM Usage: 7.45 GB / 83.47 GB
# [Resource Log | Step 511] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.7%, RAM Usage: 7.42 GB / 83.47 GB
# [Resource Log | Step 516] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.43 GB / 83.47 GB
# [Resource Log | Step 521] GPU Memory Used: 20.75 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.42 GB / 83.47 GB
# * Run finished. Uploading logs to Trackio (please wait...)
# Total FLOPs during training: 1.4481788973613056e+18

# %%
from datasets import load_dataset
from trl import SFTTrainer, SFTConfig
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch
import evaluate
from transformers import TrainerCallback
import time
from huggingface_hub import login
from pynvml import nvmlInit, nvmlDeviceGetHandleByIndex, nvmlDeviceGetMemoryInfo
import pynvml
import psutil
from peft import AdaLoraConfig, get_peft_model
from accelerate import init_empty_weights, load_checkpoint_and_dispatch

torch.cuda.empty_cache()
print("login")

login(token="YourToken")

print("data is loading")

ds_train = load_dataset('csv', data_files='./drive/MyDrive/text_only_train_data.csv')
ds_val = load_dataset('csv', data_files={'validation':'./drive/MyDrive/text_only_val_data.csv'})

train = ds_train["train"]

val = ds_val["validation"]

# Optionally add prefix on the validation set for instruction tuning
def add_prefix(example):
    prefix = "Summarize the following document: "
    example["document"] = prefix + example["document"]
    return example

train = train.map(add_prefix)
val = val.map(add_prefix)

print("model loading")

model_id = "Qwen/Qwen2.5-7B-Instruct"
tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForCausalLM.from_pretrained(model_id, dtype=torch.bfloat16, device_map="auto")

print("Loading ROUGE metric...")
rouge = evaluate.load("rouge")

def compute_metrics(eval_preds):
    predictions, labels = eval_preds
    # decode token IDs into strings if needed (tokenizer needed here)
    decoded_preds = tokenizer.batch_decode(predictions, skip_special_tokens=True)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)

    # Run rouge evaluation on decoded text
    result = rouge.compute(predictions=decoded_preds, references=decoded_labels)
    print("ROUGE Log", result)
    return {
        "rouge1": result["rouge1"],
        "rouge2": result["rouge2"],
        "rougeL": result["rougeL"]
    }
class ResourceLoggingCallback(TrainerCallback):
    def __init__(self, log_interval=60):
        super().__init__()
        self.log_interval = log_interval  # seconds
        self.last_log_time = time.time()
        nvmlInit()
        self.handle = nvmlDeviceGetHandleByIndex(0)  # GPU 0

    def on_step_end(self, args, state, control, **kwargs):
        current_time = time.time()
        if current_time - self.last_log_time >= self.log_interval:
            # Log GPU memory
            mem_info = nvmlDeviceGetMemoryInfo(self.handle)
            gpu_used = mem_info.used / (1024 ** 3)
            gpu_total = mem_info.total / (1024 ** 3)

            # Log CPU/RAM usage
            cpu_percent = psutil.cpu_percent()
            ram_info = psutil.virtual_memory()

            print(f"[Resource Log | Step {state.global_step}] "
                  f"GPU Memory Used: {gpu_used:.2f} GB / {gpu_total:.2f} GB, "
                  f"CPU Usage: {cpu_percent}%, "
                  f"RAM Usage: {ram_info.used / (1024 ** 3):.2f} GB / {ram_info.total / (1024 ** 3):.2f} GB")

            self.last_log_time = current_time

    def on_train_end(self, args, state, control, **kwargs):
        total_flos = getattr(state, 'total_flos', None)
        if total_flos is not None:
            print(f"Total FLOPs during training: {total_flos}")
        else:
            print("Total FLOPs information not available.")

print(model_id)
print("training")
adalora_config = AdaLoraConfig(
    init_r=64,
    target_r = 32,# rank for LoRA matrices
    target_modules=["q_proj", "v_proj"],  # modules to adapt
    lora_alpha=64,
    lora_dropout=0.1,
    bias="none",
    task_type="CAUSAL_LM",
    total_step=471
)

# Wrap the base model with AdaLoRA PEFT model
ada_lora_model = get_peft_model(model, adalora_config)

training_args = SFTConfig(
    dataset_text_field="document",
    learning_rate=2e-4,
    per_device_train_batch_size=1, # Further reduced batch size
    per_device_eval_batch_size=1, # Further reduced eval batch size
    gradient_accumulation_steps=64, # Increased gradient accumulation steps
    num_train_epochs=2,
    report_to=["trackio"],  # Add this to save checkpoints
    save_strategy="epoch",
    output_dir = "./drive/MyDrive/Results_AdaLora/Qwen/sft-qwen-ada-lora",  # Save checkpoint at end of each epoch
    gradient_checkpointing=True # Enable gradient checkpointing
)

trainer = SFTTrainer(
        model=ada_lora_model,  # reload or clone model if needed
        train_dataset=train,
        eval_dataset=val,
        args=training_args,
        compute_metrics=compute_metrics,
        callbacks=[ResourceLoggingCallback(log_interval=120)],
        processing_class=tokenizer,
    )
trainer.train()
trainer.save_model("./drive/MyDrive/Results_AdaLora/Qwen/my_trained_qwen_model")
trainer.save_state()
# Out:
# login
# data is loading
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Map:   0%|          | 0/16820 [00:00<?, ? examples/s]
# Map:   0%|          | 0/2102 [00:00<?, ? examples/s]
# model loading
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/663 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/3.95G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/3.56G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/3.86G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/3.86G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/243 [00:00<?, ?B/s]
# Loading ROUGE metric...
# Downloading builder script: 0.00B [00:00, ?B/s]
# Qwen/Qwen2.5-7B-Instruct
# training
# Adding EOS to train dataset:   0%|          | 0/16820 [00:00<?, ? examples/s]
# Tokenizing train dataset:   0%|          | 0/16820 [00:00<?, ? examples/s]
# Truncating train dataset:   0%|          | 0/16820 [00:00<?, ? examples/s]
# Adding EOS to eval dataset:   0%|          | 0/2102 [00:00<?, ? examples/s]
# Tokenizing eval dataset:   0%|          | 0/2102 [00:00<?, ? examples/s]
# Truncating eval dataset:   0%|          | 0/2102 [00:00<?, ? examples/s]
# The model is already on multiple devices. Skipping the move to device specified in `args`.
# The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'bos_token_id': None, 'pad_token_id': 151643}.
# * Trackio project initialized: huggingface
# * Trackio metrics will be synced to Hugging Face Dataset: Dali-bot/trackio-dataset
# * Found existing space: https://huggingface.co/spaces/Dali-bot/trackio
# * View dashboard by going to: https://Dali-bot-trackio.hf.space/
# <div><iframe src="https://Dali-bot-trackio.hf.space/" width="100%" height="1000px" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# * Created new run: Dali-bot-1762796536
# [Resource Log | Step 1] GPU Memory Used: 17.92 GB / 40.00 GB, CPU Usage: 12.1%, RAM Usage: 7.78 GB / 83.47 GB
#     <div>
#
#       <progress value='526' max='526' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [526/526 3:08:35, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>123.303800</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>81.876700</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>53.669000</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>50.023600</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>43.522800</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>39.156800</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>35.221700</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>31.432500</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>27.581700</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>23.681700</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>19.685000</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>15.585700</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>11.395600</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>7.096000</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>3.419100</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>3.277500</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>2.631300</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>2.484600</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>2.387200</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>2.393400</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>2.352400</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>2.305000</td>
#     </tr>
#     <tr>
#       <td>230</td>
#       <td>2.312300</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>2.279500</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>2.236800</td>
#     </tr>
#     <tr>
#       <td>260</td>
#       <td>2.232600</td>
#     </tr>
#     <tr>
#       <td>270</td>
#       <td>2.201900</td>
#     </tr>
#     <tr>
#       <td>280</td>
#       <td>2.191000</td>
#     </tr>
#     <tr>
#       <td>290</td>
#       <td>2.157000</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>2.154800</td>
#     </tr>
#     <tr>
#       <td>310</td>
#       <td>2.151200</td>
#     </tr>
#     <tr>
#       <td>320</td>
#       <td>2.118500</td>
#     </tr>
#     <tr>
#       <td>330</td>
#       <td>2.101200</td>
#     </tr>
#     <tr>
#       <td>340</td>
#       <td>2.102900</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>2.052600</td>
#     </tr>
#     <tr>
#       <td>360</td>
#       <td>2.044500</td>
#     </tr>
#     <tr>
#       <td>370</td>
#       <td>2.042600</td>
#     </tr>
#     <tr>
#       <td>380</td>
#       <td>2.036200</td>
#     </tr>
#     <tr>
#       <td>390</td>
#       <td>2.019300</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>1.985900</td>
#     </tr>
#     <tr>
#       <td>410</td>
#       <td>1.991800</td>
#     </tr>
#     <tr>
#       <td>420</td>
#       <td>1.942600</td>
#     </tr>
#     <tr>
#       <td>430</td>
#       <td>1.920700</td>
#     </tr>
#     <tr>
#       <td>440</td>
#       <td>1.909500</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>1.912500</td>
#     </tr>
#     <tr>
#       <td>460</td>
#       <td>1.886000</td>
#     </tr>
#     <tr>
#       <td>470</td>
#       <td>1.855200</td>
#     </tr>
#     <tr>
#       <td>480</td>
#       <td>1.857500</td>
#     </tr>
#     <tr>
#       <td>490</td>
#       <td>1.822100</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>1.839800</td>
#     </tr>
#     <tr>
#       <td>510</td>
#       <td>1.797600</td>
#     </tr>
#     <tr>
#       <td>520</td>
#       <td>1.800100</td>
#     </tr>
#   </tbody>
# </table><p>
# [Resource Log | Step 7] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.80 GB / 83.47 GB
# [Resource Log | Step 13] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 7.80 GB / 83.47 GB
# [Resource Log | Step 19] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.79 GB / 83.47 GB
# [Resource Log | Step 25] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 7.78 GB / 83.47 GB
# [Resource Log | Step 31] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.75 GB / 83.47 GB
# [Resource Log | Step 37] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.79 GB / 83.47 GB
# [Resource Log | Step 43] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 7.79 GB / 83.47 GB
# [Resource Log | Step 49] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.7%, RAM Usage: 7.76 GB / 83.47 GB
# [Resource Log | Step 55] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 7.78 GB / 83.47 GB
# [Resource Log | Step 61] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.79 GB / 83.47 GB
# [Resource Log | Step 67] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.76 GB / 83.47 GB
# [Resource Log | Step 73] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 7.73 GB / 83.47 GB
# [Resource Log | Step 79] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.74 GB / 83.47 GB
# [Resource Log | Step 85] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 7.72 GB / 83.47 GB
# [Resource Log | Step 91] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.74 GB / 83.47 GB
# [Resource Log | Step 97] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.74 GB / 83.47 GB
# [Resource Log | Step 103] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 7.75 GB / 83.47 GB
# [Resource Log | Step 109] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.74 GB / 83.47 GB
# [Resource Log | Step 115] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.76 GB / 83.47 GB
# [Resource Log | Step 121] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.74 GB / 83.47 GB
# [Resource Log | Step 127] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.73 GB / 83.47 GB
# [Resource Log | Step 133] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 7.72 GB / 83.47 GB
# [Resource Log | Step 139] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.76 GB / 83.47 GB
# [Resource Log | Step 145] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.74 GB / 83.47 GB
# [Resource Log | Step 151] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.73 GB / 83.47 GB
# [Resource Log | Step 157] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.74 GB / 83.47 GB
# [Resource Log | Step 163] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 7.72 GB / 83.47 GB
# [Resource Log | Step 169] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.73 GB / 83.47 GB
# [Resource Log | Step 175] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.72 GB / 83.47 GB
# [Resource Log | Step 181] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.72 GB / 83.47 GB
# [Resource Log | Step 187] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.75 GB / 83.47 GB
# [Resource Log | Step 193] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 7.71 GB / 83.47 GB
# [Resource Log | Step 199] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.72 GB / 83.47 GB
# [Resource Log | Step 205] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.74 GB / 83.47 GB
# [Resource Log | Step 211] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.74 GB / 83.47 GB
# [Resource Log | Step 217] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.73 GB / 83.47 GB
# [Resource Log | Step 223] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 7.71 GB / 83.47 GB
# [Resource Log | Step 229] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.71 GB / 83.47 GB
# [Resource Log | Step 235] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.73 GB / 83.47 GB
# [Resource Log | Step 241] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.72 GB / 83.47 GB
# [Resource Log | Step 247] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.73 GB / 83.47 GB
# [Resource Log | Step 253] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 7.70 GB / 83.47 GB
# [Resource Log | Step 259] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.71 GB / 83.47 GB
# [Resource Log | Step 265] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.73 GB / 83.47 GB
# [Resource Log | Step 271] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.69 GB / 83.47 GB
# [Resource Log | Step 277] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.72 GB / 83.47 GB
# [Resource Log | Step 283] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.71 GB / 83.47 GB
# [Resource Log | Step 289] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.72 GB / 83.47 GB
# [Resource Log | Step 295] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.69 GB / 83.47 GB
# [Resource Log | Step 301] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.72 GB / 83.47 GB
# [Resource Log | Step 307] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 7.69 GB / 83.47 GB
# [Resource Log | Step 313] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.71 GB / 83.47 GB
# [Resource Log | Step 319] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.72 GB / 83.47 GB
# [Resource Log | Step 325] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 7.69 GB / 83.47 GB
# [Resource Log | Step 331] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.71 GB / 83.47 GB
# [Resource Log | Step 337] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 7.71 GB / 83.47 GB
# [Resource Log | Step 343] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.70 GB / 83.47 GB
# [Resource Log | Step 349] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.70 GB / 83.47 GB
# [Resource Log | Step 355] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 7.72 GB / 83.47 GB
# [Resource Log | Step 361] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.70 GB / 83.47 GB
# [Resource Log | Step 367] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.71 GB / 83.47 GB
# [Resource Log | Step 373] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.71 GB / 83.47 GB
# [Resource Log | Step 379] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.70 GB / 83.47 GB
# [Resource Log | Step 385] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.70 GB / 83.47 GB
# [Resource Log | Step 391] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.71 GB / 83.47 GB
# [Resource Log | Step 397] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 7.71 GB / 83.47 GB
# [Resource Log | Step 403] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.69 GB / 83.47 GB
# [Resource Log | Step 409] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.73 GB / 83.47 GB
# [Resource Log | Step 415] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.72 GB / 83.47 GB
# [Resource Log | Step 421] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.72 GB / 83.47 GB
# [Resource Log | Step 427] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.71 GB / 83.47 GB
# [Resource Log | Step 433] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.72 GB / 83.47 GB
# [Resource Log | Step 439] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.73 GB / 83.47 GB
# [Resource Log | Step 445] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.70 GB / 83.47 GB
# [Resource Log | Step 451] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.70 GB / 83.47 GB
# [Resource Log | Step 457] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 7.70 GB / 83.47 GB
# [Resource Log | Step 463] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.69 GB / 83.47 GB
# [Resource Log | Step 469] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.70 GB / 83.47 GB
# [Resource Log | Step 475] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.70 GB / 83.47 GB
# [Resource Log | Step 481] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.74 GB / 83.47 GB
# [Resource Log | Step 487] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.71 GB / 83.47 GB
# [Resource Log | Step 493] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.71 GB / 83.47 GB
# [Resource Log | Step 499] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.70 GB / 83.47 GB
# [Resource Log | Step 505] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.71 GB / 83.47 GB
# [Resource Log | Step 511] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 7.71 GB / 83.47 GB
# [Resource Log | Step 517] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.70 GB / 83.47 GB
# [Resource Log | Step 523] GPU Memory Used: 17.98 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.72 GB / 83.47 GB
# * Run finished. Uploading logs to Trackio (please wait...)
# Total FLOPs during training: 1.4655576670922342e+18

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
