# %%
# !pip install datasets transformers trl evaluate huggingface_hub pynvml psutil rouge_score trackio
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (4.0.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.57.1)
# Collecting trl
#   Downloading trl-0.25.0-py3-none-any.whl.metadata (11 kB)
# Collecting evaluate
#   Downloading evaluate-0.4.6-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (0.36.0)
# Requirement already satisfied: pynvml in /usr/local/lib/python3.12/dist-packages (12.0.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (5.9.5)
# Collecting rouge_score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Collecting trackio
#   Downloading trackio-0.8.1-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets) (3.20.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.32.4)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.12/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from datasets) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.6.2)
# Requirement already satisfied: accelerate>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from trl) (1.11.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (1.2.0)
# Requirement already satisfied: nvidia-ml-py<13.0.0a0,>=12.0.0 in /usr/local/lib/python3.12/dist-packages (from pynvml) (12.575.51)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from rouge_score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (from rouge_score) (3.9.1)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.12/dist-packages (from rouge_score) (1.17.0)
# Requirement already satisfied: gradio<6.0.0,>=5.48.0 in /usr/local/lib/python3.12/dist-packages (from gradio[oauth]<6.0.0,>=5.48.0->trackio) (5.49.1)
# Requirement already satisfied: orjson<4.0.0,>=3.0 in /usr/local/lib/python3.12/dist-packages (from trackio) (3.11.4)
# Requirement already satisfied: pillow<12.0.0 in /usr/local/lib/python3.12/dist-packages (from trackio) (11.3.0)
# Collecting plotly<7.0.0,>=6.0.0 (from trackio)
#   Downloading plotly-6.4.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: pydub<1.0.0 in /usr/local/lib/python3.12/dist-packages (from trackio) (0.25.1)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from accelerate>=1.4.0->trl) (2.8.0+cu126)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.13.2)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in /usr/local/lib/python3.12/dist-packages (from gradio<6.0.0,>=5.48.0->gradio[oauth]<6.0.0,>=5.48.0->trackio) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio<6.0.0,>=5.48.0->gradio[oauth]<6.0.0,>=5.48.0->trackio) (4.11.0)
# Requirement already satisfied: brotli>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from gradio<6.0.0,>=5.48.0->gradio[oauth]<6.0.0,>=5.48.0->trackio) (1.2.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /usr/local/lib/python3.12/dist-packages (from gradio<6.0.0,>=5.48.0->gradio[oauth]<6.0.0,>=5.48.0->trackio) (0.121.0)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.12/dist-packages (from gradio<6.0.0,>=5.48.0->gradio[oauth]<6.0.0,>=5.48.0->trackio) (0.6.4)
# Requirement already satisfied: gradio-client==1.13.3 in /usr/local/lib/python3.12/dist-packages (from gradio<6.0.0,>=5.48.0->gradio[oauth]<6.0.0,>=5.48.0->trackio) (1.13.3)
# Requirement already satisfied: groovy~=0.1 in /usr/local/lib/python3.12/dist-packages (from gradio<6.0.0,>=5.48.0->gradio[oauth]<6.0.0,>=5.48.0->trackio) (0.1.2)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in /usr/local/lib/python3.12/dist-packages (from gradio<6.0.0,>=5.48.0->gradio[oauth]<6.0.0,>=5.48.0->trackio) (0.28.1)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.12/dist-packages (from gradio<6.0.0,>=5.48.0->gradio[oauth]<6.0.0,>=5.48.0->trackio) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio<6.0.0,>=5.48.0->gradio[oauth]<6.0.0,>=5.48.0->trackio) (3.0.3)
# Requirement already satisfied: pydantic<2.12,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio<6.0.0,>=5.48.0->gradio[oauth]<6.0.0,>=5.48.0->trackio) (2.11.10)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.12/dist-packages (from gradio<6.0.0,>=5.48.0->gradio[oauth]<6.0.0,>=5.48.0->trackio) (0.0.20)
# Requirement already satisfied: ruff>=0.9.3 in /usr/local/lib/python3.12/dist-packages (from gradio<6.0.0,>=5.48.0->gradio[oauth]<6.0.0,>=5.48.0->trackio) (0.14.3)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /usr/local/lib/python3.12/dist-packages (from gradio<6.0.0,>=5.48.0->gradio[oauth]<6.0.0,>=5.48.0->trackio) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio<6.0.0,>=5.48.0->gradio[oauth]<6.0.0,>=5.48.0->trackio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from gradio<6.0.0,>=5.48.0->gradio[oauth]<6.0.0,>=5.48.0->trackio) (0.49.3)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from gradio<6.0.0,>=5.48.0->gradio[oauth]<6.0.0,>=5.48.0->trackio) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.12/dist-packages (from gradio<6.0.0,>=5.48.0->gradio[oauth]<6.0.0,>=5.48.0->trackio) (0.20.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from gradio<6.0.0,>=5.48.0->gradio[oauth]<6.0.0,>=5.48.0->trackio) (0.38.0)
# Requirement already satisfied: websockets<16.0,>=13.0 in /usr/local/lib/python3.12/dist-packages (from gradio-client==1.13.3->gradio<6.0.0,>=5.48.0->gradio[oauth]<6.0.0,>=5.48.0->trackio) (15.0.1)
# Requirement already satisfied: authlib in /usr/local/lib/python3.12/dist-packages (from gradio[oauth]<6.0.0,>=5.48.0->trackio) (1.6.5)
# Requirement already satisfied: itsdangerous in /usr/local/lib/python3.12/dist-packages (from gradio[oauth]<6.0.0,>=5.48.0->trackio) (2.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: narwhals>=1.15.1 in /usr/local/lib/python3.12/dist-packages (from plotly<7.0.0,>=6.0.0->trackio) (2.10.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2025.10.5)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk->rouge_score) (8.3.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk->rouge_score) (1.5.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0,>=3.0->gradio<6.0.0,>=5.48.0->gradio[oauth]<6.0.0,>=5.48.0->trackio) (1.3.1)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi<1.0,>=0.115.2->gradio<6.0.0,>=5.48.0->gradio[oauth]<6.0.0,>=5.48.0->trackio) (0.0.3)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.24.1->gradio<6.0.0,>=5.48.0->gradio[oauth]<6.0.0,>=5.48.0->trackio) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio<6.0.0,>=5.48.0->gradio[oauth]<6.0.0,>=5.48.0->trackio) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<2.12,>=2.0->gradio<6.0.0,>=5.48.0->gradio[oauth]<6.0.0,>=5.48.0->trackio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<2.12,>=2.0->gradio<6.0.0,>=5.48.0->gradio[oauth]<6.0.0,>=5.48.0->trackio) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<2.12,>=2.0->gradio<6.0.0,>=5.48.0->gradio[oauth]<6.0.0,>=5.48.0->trackio) (0.4.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (3.5)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (3.4.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio<6.0.0,>=5.48.0->gradio[oauth]<6.0.0,>=5.48.0->trackio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio<6.0.0,>=5.48.0->gradio[oauth]<6.0.0,>=5.48.0->trackio) (13.9.4)
# Requirement already satisfied: cryptography in /usr/local/lib/python3.12/dist-packages (from authlib->gradio[oauth]<6.0.0,>=5.48.0->trackio) (43.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio<6.0.0,>=5.48.0->gradio[oauth]<6.0.0,>=5.48.0->trackio) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio<6.0.0,>=5.48.0->gradio[oauth]<6.0.0,>=5.48.0->trackio) (2.19.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate>=1.4.0->trl) (1.3.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography->authlib->gradio[oauth]<6.0.0,>=5.48.0->trackio) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography->authlib->gradio[oauth]<6.0.0,>=5.48.0->trackio) (2.23)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio<6.0.0,>=5.48.0->gradio[oauth]<6.0.0,>=5.48.0->trackio) (0.1.2)
# Downloading trl-0.25.0-py3-none-any.whl (462 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.8/462.8 kB 28.6 MB/s eta 0:00:00
# Downloading evaluate-0.4.6-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 7.6 MB/s eta 0:00:00
# Downloading trackio-0.8.1-py3-none-any.whl (874 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 875.0/875.0 kB 45.8 MB/s eta 0:00:00
# Downloading plotly-6.4.0-py3-none-any.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 115.4 MB/s eta 0:00:00
# Building wheels for collected packages: rouge_score
#   Building wheel for rouge_score (setup.py) ... done
#   Created wheel for rouge_score: filename=rouge_score-0.1.2-py3-none-any.whl size=24934 sha256=bfef6e8fd5aca7be5f686f02231108adb3bdf3416b840555a841d0ab9433dda8
#   Stored in directory: /root/.cache/pip/wheels/85/9d/af/01feefbe7d55ef5468796f0c68225b6788e85d9d0a281e7a70
# Successfully built rouge_score
# Installing collected packages: plotly, rouge_score, trl, evaluate, trackio
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.24.1
#     Uninstalling plotly-5.24.1:
#       Successfully uninstalled plotly-5.24.1
# Successfully installed evaluate-0.4.6 plotly-6.4.0 rouge_score-0.1.2 trackio-0.8.1 trl-0.25.0

# %%
from datasets import load_dataset
from peft import LoraConfig
from trl import SFTTrainer, SFTConfig
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch
import evaluate
from transformers import TrainerCallback
import time
from huggingface_hub import login
from pynvml import nvmlInit, nvmlDeviceGetHandleByIndex, nvmlDeviceGetMemoryInfo
import pynvml
import psutil

print("login")

login(token="YourToken")

print("data is loading")

# Load full FINDSum dataset
ds_train = load_dataset('csv', data_files='./drive/MyDrive/text_only_train_data.csv')
ds_val = load_dataset('csv', data_files={'validation':'./drive/MyDrive/text_only_val_data.csv'})

train = ds_train["train"]

val = ds_val["validation"]

def add_prefix(example):
    prefix = "Summarize the following document: "
    example["document"] = prefix + example["document"]
    return example

train = train.map(add_prefix)
val = val.map(add_prefix)

print("model loading")

model_id_mistral = "mistralai/Mistral-7B-Instruct-v0.3"
model_ids = [{"id": model_id_mistral, "name": "mistral_4"}]

model_tokenizer_list = []

for model_id in model_ids:
    tokenizer = AutoTokenizer.from_pretrained(model_id["id"])
    model = AutoModelForCausalLM.from_pretrained(model_id["id"], dtype=torch.bfloat16, device_map="auto")
    model_tokenizer_list.append({
        "model": model,
        "tokenizer": tokenizer,
        "name": model_id["name"]
    })

print("Loading ROUGE metric...")
rouge = evaluate.load("rouge")

def compute_metrics(eval_preds):
    predictions, labels = eval_preds
    # decode token IDs into strings if needed (tokenizer needed here)
    decoded_preds = tokenizer.batch_decode(predictions, skip_special_tokens=True)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)

    # Run rouge evaluation on decoded text
    result = rouge.compute(predictions=decoded_preds, references=decoded_labels)
    print("ROUGE Log", result)
    return {
        "rouge1": result["rouge1"],
        "rouge2": result["rouge2"],
        "rougeL": result["rougeL"]
    }
class ResourceLoggingCallback(TrainerCallback):
    def __init__(self, log_interval=60):
        super().__init__()
        self.log_interval = log_interval  # seconds
        self.last_log_time = time.time()
        nvmlInit()
        self.handle = nvmlDeviceGetHandleByIndex(0)  # GPU 0

    def on_step_end(self, args, state, control, **kwargs):
        current_time = time.time()
        if current_time - self.last_log_time >= self.log_interval:
            # Log GPU memory
            mem_info = nvmlDeviceGetMemoryInfo(self.handle)
            gpu_used = mem_info.used / (1024 ** 3)
            gpu_total = mem_info.total / (1024 ** 3)

            # Log CPU/RAM usage
            cpu_percent = psutil.cpu_percent()
            ram_info = psutil.virtual_memory()

            print(f"[Resource Log | Step {state.global_step}] "
                  f"GPU Memory Used: {gpu_used:.2f} GB / {gpu_total:.2f} GB, "
                  f"CPU Usage: {cpu_percent}%, "
                  f"RAM Usage: {ram_info.used / (1024 ** 3):.2f} GB / {ram_info.total / (1024 ** 3):.2f} GB")

            self.last_log_time = current_time

    def on_train_end(self, args, state, control, **kwargs):
        total_flos = getattr(state, 'total_flos', None)
        if total_flos is not None:
            print(f"Total FLOPs during training: {total_flos}")
        else:
            print("Total FLOPs information not available.")

print(model_id)
print("training")
peft_config = LoraConfig(
    r=64,
    lora_alpha=64,
    target_modules=["q_proj", "v_proj"],
    lora_dropout=0.1,
    bias="none",
    task_type="CAUSAL_LM")

training_args = SFTConfig(
    dataset_text_field="document",
    learning_rate=2e-4,
    per_device_train_batch_size=1,
    per_device_eval_batch_size=1,
    gradient_accumulation_steps=64,
    num_train_epochs=2,
    report_to=["trackio"],
    save_strategy="epoch" ,  # Save checkpoint at end of each epoch
    gradient_checkpointing=True
)
for models in model_tokenizer_list:
    print(models["name"] +"started training")
    training_args.output_dir = f"./drive/MyDrive/Results_Lora/Mistral/sft-lora-{models['name']}"
    trainer = SFTTrainer(
        model=model,
        train_dataset=train,
        eval_dataset=val,
        peft_config=peft_config,
        args=training_args,
        compute_metrics=compute_metrics,
        callbacks=[ResourceLoggingCallback(log_interval=120)],
        processing_class=tokenizer  # Pass tokenizer here, not as "tokenizer"
    )

    trainer.train()
    trainer.save_model("./drive/MyDrive/Results_Lora/Mistral/my_trained__mistral_model")
    trainer.save_state()
    print(models["name"] +"finished training")
# Out:
# login
# data is loading
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Map:   0%|          | 0/16820 [00:00<?, ? examples/s]
# Map:   0%|          | 0/2102 [00:00<?, ? examples/s]
# model loading
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/587k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/601 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 3 files:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/4.55G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Loading ROUGE metric...
# Downloading builder script: 0.00B [00:00, ?B/s]
# {'id': 'mistralai/Mistral-7B-Instruct-v0.3', 'name': 'mistral_4'}
# training
# mistral_4started training
# Adding EOS to train dataset:   0%|          | 0/16820 [00:00<?, ? examples/s]
# Tokenizing train dataset:   0%|          | 0/16820 [00:00<?, ? examples/s]
# Truncating train dataset:   0%|          | 0/16820 [00:00<?, ? examples/s]
# Adding EOS to eval dataset:   0%|          | 0/2102 [00:00<?, ? examples/s]
# Tokenizing eval dataset:   0%|          | 0/2102 [00:00<?, ? examples/s]
# Truncating eval dataset:   0%|          | 0/2102 [00:00<?, ? examples/s]
# The model is already on multiple devices. Skipping the move to device specified in `args`.
# * Trackio project initialized: huggingface
# * Trackio metrics will be synced to Hugging Face Dataset: Dali-bot/trackio-dataset
# * Found existing space: https://huggingface.co/spaces/Dali-bot/trackio
# * View dashboard by going to: https://Dali-bot-trackio.hf.space/
# <div><iframe src="https://Dali-bot-trackio.hf.space/" width="100%" height="1000px" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# * Created new run: Dali-bot-1762784594
# [Resource Log | Step 1] GPU Memory Used: 15.72 GB / 40.00 GB, CPU Usage: 14.6%, RAM Usage: 5.39 GB / 83.47 GB
#     <div>
#
#       <progress value='526' max='526' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [526/526 2:53:23, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>1.579200</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.490500</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.474000</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>1.466400</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>1.467200</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>1.459000</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>1.467000</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>1.437500</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>1.437100</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.444100</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>1.439800</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>1.424500</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>1.421300</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>1.412500</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>1.424000</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>1.409500</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>1.427400</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>1.398300</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>1.402300</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>1.421300</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>1.422300</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>1.397400</td>
#     </tr>
#     <tr>
#       <td>230</td>
#       <td>1.422600</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>1.404200</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>1.379200</td>
#     </tr>
#     <tr>
#       <td>260</td>
#       <td>1.393600</td>
#     </tr>
#     <tr>
#       <td>270</td>
#       <td>1.369900</td>
#     </tr>
#     <tr>
#       <td>280</td>
#       <td>1.362200</td>
#     </tr>
#     <tr>
#       <td>290</td>
#       <td>1.348200</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>1.355800</td>
#     </tr>
#     <tr>
#       <td>310</td>
#       <td>1.372800</td>
#     </tr>
#     <tr>
#       <td>320</td>
#       <td>1.355900</td>
#     </tr>
#     <tr>
#       <td>330</td>
#       <td>1.344600</td>
#     </tr>
#     <tr>
#       <td>340</td>
#       <td>1.358500</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>1.330800</td>
#     </tr>
#     <tr>
#       <td>360</td>
#       <td>1.330500</td>
#     </tr>
#     <tr>
#       <td>370</td>
#       <td>1.348000</td>
#     </tr>
#     <tr>
#       <td>380</td>
#       <td>1.339600</td>
#     </tr>
#     <tr>
#       <td>390</td>
#       <td>1.355500</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>1.338100</td>
#     </tr>
#     <tr>
#       <td>410</td>
#       <td>1.346100</td>
#     </tr>
#     <tr>
#       <td>420</td>
#       <td>1.319100</td>
#     </tr>
#     <tr>
#       <td>430</td>
#       <td>1.314700</td>
#     </tr>
#     <tr>
#       <td>440</td>
#       <td>1.318300</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>1.332500</td>
#     </tr>
#     <tr>
#       <td>460</td>
#       <td>1.326800</td>
#     </tr>
#     <tr>
#       <td>470</td>
#       <td>1.314600</td>
#     </tr>
#     <tr>
#       <td>480</td>
#       <td>1.326200</td>
#     </tr>
#     <tr>
#       <td>490</td>
#       <td>1.308600</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>1.339000</td>
#     </tr>
#     <tr>
#       <td>510</td>
#       <td>1.314300</td>
#     </tr>
#     <tr>
#       <td>520</td>
#       <td>1.328100</td>
#     </tr>
#   </tbody>
# </table><p>
# [Resource Log | Step 8] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.37 GB / 83.47 GB
# [Resource Log | Step 15] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.38 GB / 83.47 GB
# [Resource Log | Step 22] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.36 GB / 83.47 GB
# [Resource Log | Step 29] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.36 GB / 83.47 GB
# [Resource Log | Step 36] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.34 GB / 83.47 GB
# [Resource Log | Step 43] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.33 GB / 83.47 GB
# [Resource Log | Step 50] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.35 GB / 83.47 GB
# [Resource Log | Step 57] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 5.33 GB / 83.47 GB
# [Resource Log | Step 64] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.34 GB / 83.47 GB
# [Resource Log | Step 71] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.32 GB / 83.47 GB
# [Resource Log | Step 78] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.32 GB / 83.47 GB
# [Resource Log | Step 85] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.34 GB / 83.47 GB
# [Resource Log | Step 92] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 5.33 GB / 83.47 GB
# [Resource Log | Step 99] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.32 GB / 83.47 GB
# [Resource Log | Step 106] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.34 GB / 83.47 GB
# [Resource Log | Step 113] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.33 GB / 83.47 GB
# [Resource Log | Step 120] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.32 GB / 83.47 GB
# [Resource Log | Step 127] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.31 GB / 83.47 GB
# [Resource Log | Step 134] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.32 GB / 83.47 GB
# [Resource Log | Step 141] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.32 GB / 83.47 GB
# [Resource Log | Step 148] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.31 GB / 83.47 GB
# [Resource Log | Step 155] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.30 GB / 83.47 GB
# [Resource Log | Step 162] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.32 GB / 83.47 GB
# [Resource Log | Step 169] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.29 GB / 83.47 GB
# [Resource Log | Step 176] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.33 GB / 83.47 GB
# [Resource Log | Step 183] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.29 GB / 83.47 GB
# [Resource Log | Step 190] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.30 GB / 83.47 GB
# [Resource Log | Step 197] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.31 GB / 83.47 GB
# [Resource Log | Step 204] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.31 GB / 83.47 GB
# [Resource Log | Step 211] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.29 GB / 83.47 GB
# [Resource Log | Step 218] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.28 GB / 83.47 GB
# [Resource Log | Step 225] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.30 GB / 83.47 GB
# [Resource Log | Step 232] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.32 GB / 83.47 GB
# [Resource Log | Step 239] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.30 GB / 83.47 GB
# [Resource Log | Step 246] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.28 GB / 83.47 GB
# [Resource Log | Step 253] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.31 GB / 83.47 GB
# [Resource Log | Step 260] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.29 GB / 83.47 GB
# [Resource Log | Step 267] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.31 GB / 83.47 GB
# [Resource Log | Step 274] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 5.30 GB / 83.47 GB
# [Resource Log | Step 281] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.29 GB / 83.47 GB
# [Resource Log | Step 288] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.30 GB / 83.47 GB
# [Resource Log | Step 295] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 5.32 GB / 83.47 GB
# [Resource Log | Step 302] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.31 GB / 83.47 GB
# [Resource Log | Step 309] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.29 GB / 83.47 GB
# [Resource Log | Step 316] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 5.33 GB / 83.47 GB
# [Resource Log | Step 323] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.33 GB / 83.47 GB
# [Resource Log | Step 330] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.30 GB / 83.47 GB
# [Resource Log | Step 337] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.31 GB / 83.47 GB
# [Resource Log | Step 344] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.30 GB / 83.47 GB
# [Resource Log | Step 351] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.30 GB / 83.47 GB
# [Resource Log | Step 358] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.28 GB / 83.47 GB
# [Resource Log | Step 365] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.34 GB / 83.47 GB
# [Resource Log | Step 372] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.32 GB / 83.47 GB
# [Resource Log | Step 379] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.29 GB / 83.47 GB
# [Resource Log | Step 386] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.31 GB / 83.47 GB
# [Resource Log | Step 393] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.32 GB / 83.47 GB
# [Resource Log | Step 400] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.32 GB / 83.47 GB
# [Resource Log | Step 407] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.30 GB / 83.47 GB
# [Resource Log | Step 414] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.31 GB / 83.47 GB
# [Resource Log | Step 421] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.31 GB / 83.47 GB
# [Resource Log | Step 428] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.30 GB / 83.47 GB
# [Resource Log | Step 435] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.31 GB / 83.47 GB
# [Resource Log | Step 442] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.33 GB / 83.47 GB
# [Resource Log | Step 449] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.33 GB / 83.47 GB
# [Resource Log | Step 456] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.31 GB / 83.47 GB
# [Resource Log | Step 463] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.30 GB / 83.47 GB
# [Resource Log | Step 470] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.31 GB / 83.47 GB
# [Resource Log | Step 477] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.29 GB / 83.47 GB
# [Resource Log | Step 484] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.32 GB / 83.47 GB
# [Resource Log | Step 491] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.32 GB / 83.47 GB
# [Resource Log | Step 498] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.30 GB / 83.47 GB
# [Resource Log | Step 505] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.31 GB / 83.47 GB
# [Resource Log | Step 512] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.30 GB / 83.47 GB
# [Resource Log | Step 519] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.31 GB / 83.47 GB
# [Resource Log | Step 526] GPU Memory Used: 15.77 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.30 GB / 83.47 GB
# * Run finished. Uploading logs to Trackio (please wait...)
# Total FLOPs during training: 1.475945806430208e+18
# mistral_4finished training

# %%
from datasets import load_dataset
from peft import LoraConfig
from trl import SFTTrainer, SFTConfig
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch
import evaluate
from transformers import TrainerCallback
import time
from huggingface_hub import login
from pynvml import nvmlInit, nvmlDeviceGetHandleByIndex, nvmlDeviceGetMemoryInfo
import pynvml
import psutil

print("login")

login(token="YourToken")

print("data is loading")

# Load full FINDSum dataset
ds_train = load_dataset('csv', data_files='./drive/MyDrive/text_only_train_data.csv')
ds_val = load_dataset('csv', data_files={'validation':'./drive/MyDrive/text_only_val_data.csv'})

train = ds_train["train"]

val = ds_val["validation"]

def add_prefix(example):
    prefix = "Summarize the following document: "
    example["document"] = prefix + example["document"]
    return example

train = train.map(add_prefix)
val = val.map(add_prefix)

print("model loading")

model_id_qwen2_5 = "Qwen/Qwen2.5-7B-Instruct"
model_ids = [{"id": model_id_qwen2_5, "name": "qwen_4"}]

model_tokenizer_list = []

for model_id in model_ids:
    tokenizer = AutoTokenizer.from_pretrained(model_id["id"])
    model = AutoModelForCausalLM.from_pretrained(model_id["id"], dtype=torch.bfloat16, device_map="auto")
    model_tokenizer_list.append({
        "model": model,
        "tokenizer": tokenizer,
        "name": model_id["name"]
    })

print("Loading ROUGE metric...")
rouge = evaluate.load("rouge")

def compute_metrics(eval_preds):
    predictions, labels = eval_preds
    # decode token IDs into strings if needed (tokenizer needed here)
    decoded_preds = tokenizer.batch_decode(predictions, skip_special_tokens=True)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)

    # Run rouge evaluation on decoded text
    result = rouge.compute(predictions=decoded_preds, references=decoded_labels)
    print("ROUGE Log", result)
    return {
        "rouge1": result["rouge1"],
        "rouge2": result["rouge2"],
        "rougeL": result["rougeL"]
    }
class ResourceLoggingCallback(TrainerCallback):
    def __init__(self, log_interval=60):
        super().__init__()
        self.log_interval = log_interval  # seconds
        self.last_log_time = time.time()
        nvmlInit()
        self.handle = nvmlDeviceGetHandleByIndex(0)  # GPU 0

    def on_step_end(self, args, state, control, **kwargs):
        current_time = time.time()
        if current_time - self.last_log_time >= self.log_interval:
            # Log GPU memory
            mem_info = nvmlDeviceGetMemoryInfo(self.handle)
            gpu_used = mem_info.used / (1024 ** 3)
            gpu_total = mem_info.total / (1024 ** 3)

            # Log CPU/RAM usage
            cpu_percent = psutil.cpu_percent()
            ram_info = psutil.virtual_memory()

            print(f"[Resource Log | Step {state.global_step}] "
                  f"GPU Memory Used: {gpu_used:.2f} GB / {gpu_total:.2f} GB, "
                  f"CPU Usage: {cpu_percent}%, "
                  f"RAM Usage: {ram_info.used / (1024 ** 3):.2f} GB / {ram_info.total / (1024 ** 3):.2f} GB")

            self.last_log_time = current_time

    def on_train_end(self, args, state, control, **kwargs):
        total_flos = getattr(state, 'total_flos', None)
        if total_flos is not None:
            print(f"Total FLOPs during training: {total_flos}")
        else:
            print("Total FLOPs information not available.")

print(model_id)
print("training")
peft_config = LoraConfig(
    r=64,
    lora_alpha=16,
    target_modules=["q_proj", "v_proj"],
    lora_dropout=0.1,
    bias="none",
    task_type="CAUSAL_LM")

training_args = SFTConfig(
    dataset_text_field="document",
    learning_rate=2e-4,
    per_device_train_batch_size=1,
    per_device_eval_batch_size=1,
    gradient_accumulation_steps=64,
    num_train_epochs=2,
    report_to=["trackio"],
    save_strategy="epoch" ,  # Save checkpoint at end of each epoch
    gradient_checkpointing=True
)
for models in model_tokenizer_list:
    print(models["name"] +"started training")
    training_args.output_dir = f"./drive/MyDrive/Results_Lora/Qwen/sft-lora-{models['name']}"
    trainer = SFTTrainer(
        model=model,
        train_dataset=train,
        eval_dataset=val,
        peft_config=peft_config,
        args=training_args,
        compute_metrics=compute_metrics,
        callbacks=[ResourceLoggingCallback(log_interval=120)],
        processing_class=tokenizer  # Pass tokenizer here, not as "tokenizer"
    )

    trainer.train()
    trainer.save_model("./drive/MyDrive/Results_Lora/Qwen/my_trained_qwen_model")
    trainer.save_state()
    print(models["name"] +"finished training")
# Out:
# login
# data is loading
# Map:   0%|          | 0/16820 [00:00<?, ? examples/s]
# Map:   0%|          | 0/2102 [00:00<?, ? examples/s]
# model loading
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/663 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/3.95G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/3.86G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/3.86G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/3.56G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/243 [00:00<?, ?B/s]
# Loading ROUGE metric...
# {'id': 'Qwen/Qwen2.5-7B-Instruct', 'name': 'qwen_4'}
# training
# qwen_4started training
# Adding EOS to train dataset:   0%|          | 0/16820 [00:00<?, ? examples/s]
# Tokenizing train dataset:   0%|          | 0/16820 [00:00<?, ? examples/s]
# Truncating train dataset:   0%|          | 0/16820 [00:00<?, ? examples/s]
# Adding EOS to eval dataset:   0%|          | 0/2102 [00:00<?, ? examples/s]
# Tokenizing eval dataset:   0%|          | 0/2102 [00:00<?, ? examples/s]
# Truncating eval dataset:   0%|          | 0/2102 [00:00<?, ? examples/s]
# The model is already on multiple devices. Skipping the move to device specified in `args`.
# The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'bos_token_id': None, 'pad_token_id': 151643}.
# * Created new run: Dali-bot-1762796197
# [Resource Log | Step 1] GPU Memory Used: 17.92 GB / 40.00 GB, CPU Usage: 5.1%, RAM Usage: 7.99 GB / 83.47 GB
#     <div>
#
#       <progress value='526' max='526' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [526/526 2:42:55, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>1.742800</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.666200</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.627100</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>1.617200</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>1.607800</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>1.601900</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>1.600800</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>1.583000</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>1.582800</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.579700</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>1.585400</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>1.567200</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>1.566300</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>1.560400</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>1.573100</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>1.560000</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>1.571900</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>1.543500</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>1.562300</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>1.582300</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>1.581700</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>1.553900</td>
#     </tr>
#     <tr>
#       <td>230</td>
#       <td>1.576000</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>1.564400</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>1.550600</td>
#     </tr>
#     <tr>
#       <td>260</td>
#       <td>1.566800</td>
#     </tr>
#     <tr>
#       <td>270</td>
#       <td>1.557700</td>
#     </tr>
#     <tr>
#       <td>280</td>
#       <td>1.558100</td>
#     </tr>
#     <tr>
#       <td>290</td>
#       <td>1.543200</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>1.556600</td>
#     </tr>
#     <tr>
#       <td>310</td>
#       <td>1.573700</td>
#     </tr>
#     <tr>
#       <td>320</td>
#       <td>1.558800</td>
#     </tr>
#     <tr>
#       <td>330</td>
#       <td>1.549400</td>
#     </tr>
#     <tr>
#       <td>340</td>
#       <td>1.570400</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>1.542900</td>
#     </tr>
#     <tr>
#       <td>360</td>
#       <td>1.546400</td>
#     </tr>
#     <tr>
#       <td>370</td>
#       <td>1.560000</td>
#     </tr>
#     <tr>
#       <td>380</td>
#       <td>1.562200</td>
#     </tr>
#     <tr>
#       <td>390</td>
#       <td>1.567200</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>1.547200</td>
#     </tr>
#     <tr>
#       <td>410</td>
#       <td>1.569000</td>
#     </tr>
#     <tr>
#       <td>420</td>
#       <td>1.533600</td>
#     </tr>
#     <tr>
#       <td>430</td>
#       <td>1.531400</td>
#     </tr>
#     <tr>
#       <td>440</td>
#       <td>1.535900</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>1.552700</td>
#     </tr>
#     <tr>
#       <td>460</td>
#       <td>1.545100</td>
#     </tr>
#     <tr>
#       <td>470</td>
#       <td>1.529200</td>
#     </tr>
#     <tr>
#       <td>480</td>
#       <td>1.547000</td>
#     </tr>
#     <tr>
#       <td>490</td>
#       <td>1.527400</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>1.559800</td>
#     </tr>
#     <tr>
#       <td>510</td>
#       <td>1.530700</td>
#     </tr>
#     <tr>
#       <td>520</td>
#       <td>1.545000</td>
#     </tr>
#   </tbody>
# </table><p>
# [Resource Log | Step 8] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.98 GB / 83.47 GB
# [Resource Log | Step 15] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 7.97 GB / 83.47 GB
# [Resource Log | Step 22] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.97 GB / 83.47 GB
# [Resource Log | Step 29] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.97 GB / 83.47 GB
# [Resource Log | Step 36] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 7.97 GB / 83.47 GB
# [Resource Log | Step 43] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.97 GB / 83.47 GB
# [Resource Log | Step 50] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.97 GB / 83.47 GB
# [Resource Log | Step 57] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 7.94 GB / 83.47 GB
# [Resource Log | Step 64] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.95 GB / 83.47 GB
# [Resource Log | Step 71] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.94 GB / 83.47 GB
# [Resource Log | Step 78] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 7.95 GB / 83.47 GB
# [Resource Log | Step 85] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.93 GB / 83.47 GB
# [Resource Log | Step 92] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.94 GB / 83.47 GB
# [Resource Log | Step 99] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 7.94 GB / 83.47 GB
# [Resource Log | Step 106] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.94 GB / 83.47 GB
# [Resource Log | Step 113] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.94 GB / 83.47 GB
# [Resource Log | Step 120] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 7.92 GB / 83.47 GB
# [Resource Log | Step 127] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.94 GB / 83.47 GB
# [Resource Log | Step 134] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.95 GB / 83.47 GB
# [Resource Log | Step 141] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 7.93 GB / 83.47 GB
# [Resource Log | Step 148] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.95 GB / 83.47 GB
# [Resource Log | Step 155] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.92 GB / 83.47 GB
# [Resource Log | Step 162] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.91 GB / 83.47 GB
# [Resource Log | Step 169] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.92 GB / 83.47 GB
# [Resource Log | Step 176] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.92 GB / 83.47 GB
# [Resource Log | Step 183] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.93 GB / 83.47 GB
# [Resource Log | Step 190] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.93 GB / 83.47 GB
# [Resource Log | Step 197] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.90 GB / 83.47 GB
# [Resource Log | Step 204] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 7.91 GB / 83.47 GB
# [Resource Log | Step 211] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.90 GB / 83.47 GB
# [Resource Log | Step 218] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.92 GB / 83.47 GB
# [Resource Log | Step 225] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 7.89 GB / 83.47 GB
# [Resource Log | Step 232] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.92 GB / 83.47 GB
# [Resource Log | Step 239] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.90 GB / 83.47 GB
# [Resource Log | Step 246] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 7.91 GB / 83.47 GB
# [Resource Log | Step 253] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.91 GB / 83.47 GB
# [Resource Log | Step 260] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.90 GB / 83.47 GB
# [Resource Log | Step 267] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.93 GB / 83.47 GB
# [Resource Log | Step 274] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.92 GB / 83.47 GB
# [Resource Log | Step 281] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.91 GB / 83.47 GB
# [Resource Log | Step 288] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.90 GB / 83.47 GB
# [Resource Log | Step 295] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.91 GB / 83.47 GB
# [Resource Log | Step 302] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 7.90 GB / 83.47 GB
# [Resource Log | Step 309] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.90 GB / 83.47 GB
# [Resource Log | Step 316] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.91 GB / 83.47 GB
# [Resource Log | Step 323] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 7.91 GB / 83.47 GB
# [Resource Log | Step 330] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.89 GB / 83.47 GB
# [Resource Log | Step 337] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.90 GB / 83.47 GB
# [Resource Log | Step 344] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 7.88 GB / 83.47 GB
# [Resource Log | Step 351] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.90 GB / 83.47 GB
# [Resource Log | Step 358] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.90 GB / 83.47 GB
# [Resource Log | Step 365] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 7.90 GB / 83.47 GB
# [Resource Log | Step 372] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.93 GB / 83.47 GB
# [Resource Log | Step 379] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.93 GB / 83.47 GB
# [Resource Log | Step 386] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 7.91 GB / 83.47 GB
# [Resource Log | Step 393] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.90 GB / 83.47 GB
# [Resource Log | Step 400] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.89 GB / 83.47 GB
# [Resource Log | Step 407] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 7.90 GB / 83.47 GB
# [Resource Log | Step 414] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.92 GB / 83.47 GB
# [Resource Log | Step 421] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.93 GB / 83.47 GB
# [Resource Log | Step 428] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 7.91 GB / 83.47 GB
# [Resource Log | Step 435] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 7.90 GB / 83.47 GB
# [Resource Log | Step 442] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.88 GB / 83.47 GB
# [Resource Log | Step 449] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.92 GB / 83.47 GB
# [Resource Log | Step 456] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.3%, RAM Usage: 7.92 GB / 83.47 GB
# [Resource Log | Step 463] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.90 GB / 83.47 GB
# [Resource Log | Step 470] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.91 GB / 83.47 GB
# [Resource Log | Step 477] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 7.92 GB / 83.47 GB
# [Resource Log | Step 484] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 7.92 GB / 83.47 GB
# [Resource Log | Step 491] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.90 GB / 83.47 GB
# [Resource Log | Step 498] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 7.92 GB / 83.47 GB
# [Resource Log | Step 505] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.91 GB / 83.47 GB
# [Resource Log | Step 512] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 7.92 GB / 83.47 GB
# [Resource Log | Step 519] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 7.90 GB / 83.47 GB
# [Resource Log | Step 526] GPU Memory Used: 17.96 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 7.91 GB / 83.47 GB
# * Run finished. Uploading logs to Trackio (please wait...)
# Total FLOPs during training: 1.4655569147618918e+18
# qwen_4finished training

# %%
from datasets import load_dataset
from peft import LoraConfig
from trl import SFTTrainer, SFTConfig
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch
import evaluate
from transformers import TrainerCallback
import time
from huggingface_hub import login
from pynvml import nvmlInit, nvmlDeviceGetHandleByIndex, nvmlDeviceGetMemoryInfo
import pynvml
import psutil

print("login")

login(token="YourToken")

print("data is loading")

# Load full FINDSum dataset
ds_train = load_dataset('csv', data_files='./drive/MyDrive/text_only_train_data.csv')
ds_val = load_dataset('csv', data_files={'validation':'./drive/MyDrive/text_only_val_data.csv'})

train = ds_train["train"]

val = ds_val["validation"]

def add_prefix(example):
    prefix = "Summarize the following document: "
    example["document"] = prefix + example["document"]
    return example

train = train.map(add_prefix)
val = val.map(add_prefix)

print("model loading")

model_id_cohereLabs = "CohereLabs/c4ai-command-r7b-12-2024"
model_ids = [{"id": model_id_cohereLabs, "name": "coherelabs_4"}]

model_tokenizer_list = []

for model_id in model_ids:
    tokenizer = AutoTokenizer.from_pretrained(model_id["id"])
    model = AutoModelForCausalLM.from_pretrained(model_id["id"], dtype=torch.bfloat16, device_map="auto")
    model_tokenizer_list.append({
        "model": model,
        "tokenizer": tokenizer,
        "name": model_id["name"]
    })

print("Loading ROUGE metric...")
rouge = evaluate.load("rouge")

def compute_metrics(eval_preds):
    predictions, labels = eval_preds
    # decode token IDs into strings if needed (tokenizer needed here)
    decoded_preds = tokenizer.batch_decode(predictions, skip_special_tokens=True)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)

    # Run rouge evaluation on decoded text
    result = rouge.compute(predictions=decoded_preds, references=decoded_labels)
    print("ROUGE Log", result)
    return {
        "rouge1": result["rouge1"],
        "rouge2": result["rouge2"],
        "rougeL": result["rougeL"]
    }
class ResourceLoggingCallback(TrainerCallback):
    def __init__(self, log_interval=60):
        super().__init__()
        self.log_interval = log_interval  # seconds
        self.last_log_time = time.time()
        nvmlInit()
        self.handle = nvmlDeviceGetHandleByIndex(0)  # GPU 0

    def on_step_end(self, args, state, control, **kwargs):
        current_time = time.time()
        if current_time - self.last_log_time >= self.log_interval:
            # Log GPU memory
            mem_info = nvmlDeviceGetMemoryInfo(self.handle)
            gpu_used = mem_info.used / (1024 ** 3)
            gpu_total = mem_info.total / (1024 ** 3)

            # Log CPU/RAM usage
            cpu_percent = psutil.cpu_percent()
            ram_info = psutil.virtual_memory()

            print(f"[Resource Log | Step {state.global_step}] "
                  f"GPU Memory Used: {gpu_used:.2f} GB / {gpu_total:.2f} GB, "
                  f"CPU Usage: {cpu_percent}%, "
                  f"RAM Usage: {ram_info.used / (1024 ** 3):.2f} GB / {ram_info.total / (1024 ** 3):.2f} GB")

            self.last_log_time = current_time

    def on_train_end(self, args, state, control, **kwargs):
        total_flos = getattr(state, 'total_flos', None)
        if total_flos is not None:
            print(f"Total FLOPs during training: {total_flos}")
        else:
            print("Total FLOPs information not available.")

print(model_id)
print("training")
peft_config = LoraConfig(
    r=64,
    lora_alpha=64,
    target_modules=["q_proj", "v_proj"],
    lora_dropout=0.1,
    bias="none",
    task_type="CAUSAL_LM")

training_args = SFTConfig(
    dataset_text_field="document",
    learning_rate=2e-4,
    per_device_train_batch_size=1,
    per_device_eval_batch_size=1,
    gradient_accumulation_steps=64,
    num_train_epochs=2,
    report_to=["trackio"],
    save_strategy="epoch",  # Save checkpoint at end of each epoch
    gradient_checkpointing=True
)
for models in model_tokenizer_list:
    print(models["name"] +"started training")
    training_args.output_dir = f"./drive/MyDrive/Results_Lora/Command/sft-lora-{models['name']}"
    trainer = SFTTrainer(
        model=model,
        train_dataset=train,
        eval_dataset=val,
        peft_config=peft_config,
        args=training_args,
        compute_metrics=compute_metrics,
        callbacks=[ResourceLoggingCallback(log_interval=120)],
        processing_class=tokenizer  # Pass tokenizer here, not as "tokenizer"
    )

    trainer.train()
    trainer.save_model("./drive/MyDrive/Results_Lora/Command/my_trained_command_model")
    trainer.save_state()
    print(models["name"] +"finished training")
# Out:
# login
# data is loading
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Map:   0%|          | 0/16820 [00:00<?, ? examples/s]
# Map:   0%|          | 0/2102 [00:00<?, ? examples/s]
# model loading
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/45.0k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/20.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/664 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.02k [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/21.0k [00:00<?, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/178 [00:00<?, ?B/s]
# Loading ROUGE metric...
# Downloading builder script: 0.00B [00:00, ?B/s]
# {'id': 'CohereLabs/c4ai-command-r7b-12-2024', 'name': 'coherelabs_4'}
# training
# coherelabs_4started training
# Adding EOS to train dataset:   0%|          | 0/16820 [00:00<?, ? examples/s]
# Tokenizing train dataset:   0%|          | 0/16820 [00:00<?, ? examples/s]
# Truncating train dataset:   0%|          | 0/16820 [00:00<?, ? examples/s]
# Adding EOS to eval dataset:   0%|          | 0/2102 [00:00<?, ? examples/s]
# Tokenizing eval dataset:   0%|          | 0/2102 [00:00<?, ? examples/s]
# Truncating eval dataset:   0%|          | 0/2102 [00:00<?, ? examples/s]
# The model is already on multiple devices. Skipping the move to device specified in `args`.
# * Trackio project initialized: huggingface
# * Trackio metrics will be synced to Hugging Face Dataset: Dali-bot/trackio-dataset
# * Found existing space: https://huggingface.co/spaces/Dali-bot/trackio
# * View dashboard by going to: https://Dali-bot-trackio.hf.space/
# <div><iframe src="https://Dali-bot-trackio.hf.space/" width="100%" height="1000px" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# * Created new run: Dali-bot-1762834190
# [Resource Log | Step 1] GPU Memory Used: 20.62 GB / 40.00 GB, CPU Usage: 10.8%, RAM Usage: 5.27 GB / 83.47 GB
#     <div>
#
#       <progress value='526' max='526' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [526/526 3:13:20, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>1.785900</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.702300</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.660300</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>1.651300</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>1.646900</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>1.641600</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>1.644900</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>1.623500</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>1.621900</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.623500</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>1.629400</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>1.605800</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>1.604500</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>1.594600</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>1.609300</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>1.592900</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>1.607900</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>1.574900</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>1.591400</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>1.609900</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>1.612700</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>1.584300</td>
#     </tr>
#     <tr>
#       <td>230</td>
#       <td>1.606100</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>1.590800</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>1.575200</td>
#     </tr>
#     <tr>
#       <td>260</td>
#       <td>1.589900</td>
#     </tr>
#     <tr>
#       <td>270</td>
#       <td>1.576600</td>
#     </tr>
#     <tr>
#       <td>280</td>
#       <td>1.576500</td>
#     </tr>
#     <tr>
#       <td>290</td>
#       <td>1.561300</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>1.578300</td>
#     </tr>
#     <tr>
#       <td>310</td>
#       <td>1.591600</td>
#     </tr>
#     <tr>
#       <td>320</td>
#       <td>1.575600</td>
#     </tr>
#     <tr>
#       <td>330</td>
#       <td>1.564500</td>
#     </tr>
#     <tr>
#       <td>340</td>
#       <td>1.585600</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>1.559500</td>
#     </tr>
#     <tr>
#       <td>360</td>
#       <td>1.561000</td>
#     </tr>
#     <tr>
#       <td>370</td>
#       <td>1.576200</td>
#     </tr>
#     <tr>
#       <td>380</td>
#       <td>1.572700</td>
#     </tr>
#     <tr>
#       <td>390</td>
#       <td>1.583700</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>1.565200</td>
#     </tr>
#     <tr>
#       <td>410</td>
#       <td>1.580900</td>
#     </tr>
#     <tr>
#       <td>420</td>
#       <td>1.545400</td>
#     </tr>
#     <tr>
#       <td>430</td>
#       <td>1.540500</td>
#     </tr>
#     <tr>
#       <td>440</td>
#       <td>1.545900</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>1.564700</td>
#     </tr>
#     <tr>
#       <td>460</td>
#       <td>1.553600</td>
#     </tr>
#     <tr>
#       <td>470</td>
#       <td>1.540900</td>
#     </tr>
#     <tr>
#       <td>480</td>
#       <td>1.560000</td>
#     </tr>
#     <tr>
#       <td>490</td>
#       <td>1.538300</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>1.568900</td>
#     </tr>
#     <tr>
#       <td>510</td>
#       <td>1.545000</td>
#     </tr>
#     <tr>
#       <td>520</td>
#       <td>1.557700</td>
#     </tr>
#   </tbody>
# </table><p>
# [Resource Log | Step 7] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.31 GB / 83.47 GB
# [Resource Log | Step 13] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.30 GB / 83.47 GB
# [Resource Log | Step 19] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.30 GB / 83.47 GB
# [Resource Log | Step 25] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.30 GB / 83.47 GB
# [Resource Log | Step 31] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 5.29 GB / 83.47 GB
# [Resource Log | Step 37] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 5.29 GB / 83.47 GB
# [Resource Log | Step 43] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.30 GB / 83.47 GB
# [Resource Log | Step 49] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.29 GB / 83.47 GB
# [Resource Log | Step 55] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.26 GB / 83.47 GB
# [Resource Log | Step 61] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.28 GB / 83.47 GB
# [Resource Log | Step 67] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.28 GB / 83.47 GB
# [Resource Log | Step 73] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 5.27 GB / 83.47 GB
# [Resource Log | Step 79] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 5.26 GB / 83.47 GB
# [Resource Log | Step 85] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.28 GB / 83.47 GB
# [Resource Log | Step 91] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.26 GB / 83.47 GB
# [Resource Log | Step 97] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 5.27 GB / 83.47 GB
# [Resource Log | Step 103] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 5.26 GB / 83.47 GB
# [Resource Log | Step 109] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 5.24 GB / 83.47 GB
# [Resource Log | Step 115] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 5.24 GB / 83.47 GB
# [Resource Log | Step 121] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.26 GB / 83.47 GB
# [Resource Log | Step 127] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.26 GB / 83.47 GB
# [Resource Log | Step 133] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.25 GB / 83.47 GB
# [Resource Log | Step 139] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.24 GB / 83.47 GB
# [Resource Log | Step 145] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 5.23 GB / 83.47 GB
# [Resource Log | Step 151] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 5.25 GB / 83.47 GB
# [Resource Log | Step 157] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.25 GB / 83.47 GB
# [Resource Log | Step 163] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.26 GB / 83.47 GB
# [Resource Log | Step 169] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.23 GB / 83.47 GB
# [Resource Log | Step 175] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.22 GB / 83.47 GB
# [Resource Log | Step 181] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.24 GB / 83.47 GB
# [Resource Log | Step 187] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.19 GB / 83.47 GB
# [Resource Log | Step 193] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.22 GB / 83.47 GB
# [Resource Log | Step 199] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.23 GB / 83.47 GB
# [Resource Log | Step 205] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.22 GB / 83.47 GB
# [Resource Log | Step 211] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.20 GB / 83.47 GB
# [Resource Log | Step 217] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 5.20 GB / 83.47 GB
# [Resource Log | Step 223] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 5.21 GB / 83.47 GB
# [Resource Log | Step 229] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.20 GB / 83.47 GB
# [Resource Log | Step 235] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.23 GB / 83.47 GB
# [Resource Log | Step 241] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.23 GB / 83.47 GB
# [Resource Log | Step 247] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.21 GB / 83.47 GB
# [Resource Log | Step 253] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.20 GB / 83.47 GB
# [Resource Log | Step 259] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 5.19 GB / 83.47 GB
# [Resource Log | Step 265] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.7%, RAM Usage: 5.24 GB / 83.47 GB
# [Resource Log | Step 271] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 5.24 GB / 83.47 GB
# [Resource Log | Step 277] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.22 GB / 83.47 GB
# [Resource Log | Step 283] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 5.21 GB / 83.47 GB
# [Resource Log | Step 289] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 5.21 GB / 83.47 GB
# [Resource Log | Step 295] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.25 GB / 83.47 GB
# [Resource Log | Step 301] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 5.22 GB / 83.47 GB
# [Resource Log | Step 307] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.22 GB / 83.47 GB
# [Resource Log | Step 313] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.23 GB / 83.47 GB
# [Resource Log | Step 319] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.18 GB / 83.47 GB
# [Resource Log | Step 325] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.23 GB / 83.47 GB
# [Resource Log | Step 331] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.22 GB / 83.47 GB
# [Resource Log | Step 337] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.23 GB / 83.47 GB
# [Resource Log | Step 343] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 5.24 GB / 83.47 GB
# [Resource Log | Step 349] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 5.21 GB / 83.47 GB
# [Resource Log | Step 355] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.20 GB / 83.47 GB
# [Resource Log | Step 361] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 5.22 GB / 83.47 GB
# [Resource Log | Step 367] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.21 GB / 83.47 GB
# [Resource Log | Step 373] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 5.22 GB / 83.47 GB
# [Resource Log | Step 379] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 5.24 GB / 83.47 GB
# [Resource Log | Step 385] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.23 GB / 83.47 GB
# [Resource Log | Step 391] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 5.22 GB / 83.47 GB
# [Resource Log | Step 397] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 5.21 GB / 83.47 GB
# [Resource Log | Step 403] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 5.21 GB / 83.47 GB
# [Resource Log | Step 409] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 5.23 GB / 83.47 GB
# [Resource Log | Step 415] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 5.21 GB / 83.47 GB
# [Resource Log | Step 421] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 12.2%, RAM Usage: 6.91 GB / 83.47 GB
# [Resource Log | Step 427] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 11.2%, RAM Usage: 6.77 GB / 83.47 GB
# [Resource Log | Step 433] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 6.79 GB / 83.47 GB
# [Resource Log | Step 439] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 6.78 GB / 83.47 GB
# [Resource Log | Step 445] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 6.77 GB / 83.47 GB
# [Resource Log | Step 451] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 6.77 GB / 83.47 GB
# [Resource Log | Step 457] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 6.80 GB / 83.47 GB
# [Resource Log | Step 463] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 6.80 GB / 83.47 GB
# [Resource Log | Step 469] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 6.79 GB / 83.47 GB
# [Resource Log | Step 475] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 6.78 GB / 83.47 GB
# [Resource Log | Step 481] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.6%, RAM Usage: 6.79 GB / 83.47 GB
# [Resource Log | Step 487] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 6.79 GB / 83.47 GB
# [Resource Log | Step 493] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 6.77 GB / 83.47 GB
# [Resource Log | Step 499] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 6.81 GB / 83.47 GB
# [Resource Log | Step 505] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 6.80 GB / 83.47 GB
# [Resource Log | Step 511] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 6.81 GB / 83.47 GB
# [Resource Log | Step 517] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.4%, RAM Usage: 6.81 GB / 83.47 GB
# [Resource Log | Step 523] GPU Memory Used: 20.67 GB / 40.00 GB, CPU Usage: 10.5%, RAM Usage: 6.81 GB / 83.47 GB
# * Run finished. Uploading logs to Trackio (please wait...)
# Total FLOPs during training: 1.4481780375552e+18
# coherelabs_4finished training
